# %%
import networkx as nx
import itertools

try:
	file = open('rutas.txt',"r")
	Grafo = nx.Graph()

	lista_informacion = []
	ruta_impresion = ''
	path_min = []
	minimo = 100000
	diccionario_path = {}
	ciudades = []
	paths = []

	for row in file:
		informacionEntreCiudades = row.split(' ')

		ciudadOrigen = informacionEntreCiudades[0]
		if ciudadOrigen not in ciudades:
			ciudades.append(ciudadOrigen)

		ciudadDestino = informacionEntreCiudades[2]
		if ciudadDestino not in ciudades:
			ciudades.append(ciudadDestino)

		distanciaCiudades = int(informacionEntreCiudades[4].replace('\\n',''))

		lista_informacion.append((ciudadOrigen,ciudadDestino,distanciaCiudades))

	file.close()
except:
	var = 'Verifica el nombre del archivo y/o ubicacion e intenta nuevamente.'
	print('-'*len(var)+'\n'+var+'\n'+'-'*len(var)+'\n')
	exit()


Grafo.add_weighted_edges_from(lista_informacion)

for elemento in itertools.combinations(ciudades, 2):
	origen = elemento[0]
	destino = elemento[1]
	paths = paths + [x  for x  in nx.all_simple_paths(Grafo, origen,destino)  if len(x) > (len(Grafo)-1)]

for path in paths:
	total_weight = 0
	pairs = zip(path, path[1:])
	
	for pair in pairs:
		an_edge = Grafo.get_edge_data(pair[0], pair[1])
		total_weight += int(an_edge['weight'])
	if total_weight in diccionario_path.keys():
		diccionario_path[total_weight].append(path)
	else:
		diccionario_path[total_weight] = [path]
	print(path)
	print(total_weight)

	if total_weight  < minimo:
		minimo = total_weight
		path_min = path

for ciudad in path:
	if ciudad == destino:
		ruta_impresion += ciudad +' = ' 
	else:
		ruta_impresion += ciudad +' -> ' 
print('El camino mas corto es: '+ruta_impresion+ str(minimo))
# Out:
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Norrath', 'Straylight', 'Tristram', 'Arbre', 'Snowdin']
# 327
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Norrath', 'Straylight', 'Arbre', 'Tristram', 'Snowdin']
# 421
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Norrath', 'Tristram', 'Straylight', 'Arbre', 'Snowdin']
# 359
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Norrath', 'Tristram', 'Arbre', 'Straylight', 'Snowdin']
# 472
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Norrath', 'Arbre', 'Straylight', 'Tristram', 'Snowdin']
# 409
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Norrath', 'Arbre', 'Tristram', 'Straylight', 'Snowdin']
# 428
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Straylight', 'Norrath', 'Tristram', 'Arbre', 'Snowdin']
# 308
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Straylight', 'Norrath', 'Arbre', 'Tristram', 'Snowdin']
# 358
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Straylight', 'Tristram', 'Norrath', 'Arbre', 'Snowdin']
# 296
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Straylight', 'Tristram', 'Arbre', 'Norrath', 'Snowdin']
# 356
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Straylight', 'Arbre', 'Norrath', 'Tristram', 'Snowdin']
# 390
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Straylight', 'Arbre', 'Tristram', 'Norrath', 'Snowdin']
# 400
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Tristram', 'Norrath', 'Straylight', 'Arbre', 'Snowdin']
# 335
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Tristram', 'Norrath', 'Arbre', 'Straylight', 'Snowdin']
# 436
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Tristram', 'Straylight', 'Norrath', 'Arbre', 'Snowdin']
# 291
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Tristram', 'Straylight', 'Arbre', 'Norrath', 'Snowdin']
# 383
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Tristram', 'Arbre', 'Norrath', 'Straylight', 'Snowdin']
# 404
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Tristram', 'Arbre', 'Straylight', 'Norrath', 'Snowdin']
# 395
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Arbre', 'Norrath', 'Straylight', 'Tristram', 'Snowdin']
# 357
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Arbre', 'Norrath', 'Tristram', 'Straylight', 'Snowdin']
# 408
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Arbre', 'Straylight', 'Norrath', 'Tristram', 'Snowdin']
# 401
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Arbre', 'Straylight', 'Tristram', 'Norrath', 'Snowdin']
# 399
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Arbre', 'Tristram', 'Norrath', 'Straylight', 'Snowdin']
# 420
# ['AlphaCentauri', 'Tambi', 'Faerun', 'Arbre', 'Tristram', 'Straylight', 'Norrath', 'Snowdin']
# 367
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Faerun', 'Straylight', 'Tristram', 'Arbre', 'Snowdin']
# 413
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Faerun', 'Straylight', 'Arbre', 'Tristram', 'Snowdin']
# 507
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Faerun', 'Tristram', 'Straylight', 'Arbre', 'Snowdin']
# 440
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Faerun', 'Tristram', 'Arbre', 'Straylight', 'Snowdin']
# 553
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Faerun', 'Arbre', 'Straylight', 'Tristram', 'Snowdin']
# 506
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Faerun', 'Arbre', 'Tristram', 'Straylight', 'Snowdin']
# 525
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Straylight', 'Faerun', 'Tristram', 'Arbre', 'Snowdin']
# 389
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Straylight', 'Faerun', 'Arbre', 'Tristram', 'Snowdin']
# 455
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Straylight', 'Tristram', 'Faerun', 'Arbre', 'Snowdin']
# 388
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Straylight', 'Tristram', 'Arbre', 'Faerun', 'Snowdin']
# 362
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Straylight', 'Arbre', 'Faerun', 'Tristram', 'Snowdin']
# 482
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Straylight', 'Arbre', 'Tristram', 'Faerun', 'Snowdin']
# 390
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Tristram', 'Faerun', 'Straylight', 'Arbre', 'Snowdin']
# 421
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Tristram', 'Faerun', 'Arbre', 'Straylight', 'Snowdin']
# 533
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Tristram', 'Straylight', 'Faerun', 'Arbre', 'Snowdin']
# 393
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Tristram', 'Straylight', 'Arbre', 'Faerun', 'Snowdin']
# 394
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Tristram', 'Arbre', 'Faerun', 'Straylight', 'Snowdin']
# 506
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Tristram', 'Arbre', 'Straylight', 'Faerun', 'Snowdin']
# 395
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Arbre', 'Faerun', 'Straylight', 'Tristram', 'Snowdin']
# 443
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Arbre', 'Faerun', 'Tristram', 'Straylight', 'Snowdin']
# 489
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Arbre', 'Straylight', 'Faerun', 'Tristram', 'Snowdin']
# 471
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Arbre', 'Straylight', 'Tristram', 'Faerun', 'Snowdin']
# 378
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Arbre', 'Tristram', 'Faerun', 'Straylight', 'Snowdin']
# 490
# ['AlphaCentauri', 'Tambi', 'Norrath', 'Arbre', 'Tristram', 'Straylight', 'Faerun', 'Snowdin']
# 351
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Faerun', 'Norrath', 'Tristram', 'Arbre', 'Snowdin']
# 453
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Faerun', 'Norrath', 'Arbre', 'Tristram', 'Snowdin']
# 503
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Faerun', 'Tristram', 'Norrath', 'Arbre', 'Snowdin']
# 417
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Faerun', 'Tristram', 'Arbre', 'Norrath', 'Snowdin']
# 477
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Faerun', 'Arbre', 'Norrath', 'Tristram', 'Snowdin']
# 483
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Faerun', 'Arbre', 'Tristram', 'Norrath', 'Snowdin']
# 493
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Norrath', 'Faerun', 'Tristram', 'Arbre', 'Snowdin']
# 448
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Norrath', 'Faerun', 'Arbre', 'Tristram', 'Snowdin']
# 514
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Norrath', 'Tristram', 'Faerun', 'Arbre', 'Snowdin']
# 428
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Norrath', 'Tristram', 'Arbre', 'Faerun', 'Snowdin']
# 402
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Norrath', 'Arbre', 'Faerun', 'Tristram', 'Snowdin']
# 478
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Norrath', 'Arbre', 'Tristram', 'Faerun', 'Snowdin']
# 386
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Tristram', 'Faerun', 'Norrath', 'Arbre', 'Snowdin']
# 436
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Tristram', 'Faerun', 'Arbre', 'Norrath', 'Snowdin']
# 476
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Tristram', 'Norrath', 'Faerun', 'Arbre', 'Snowdin']
# 452
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Tristram', 'Norrath', 'Arbre', 'Faerun', 'Snowdin']
# 390
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Tristram', 'Arbre', 'Faerun', 'Norrath', 'Snowdin']
# 512
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Tristram', 'Arbre', 'Norrath', 'Faerun', 'Snowdin']
# 410
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Arbre', 'Faerun', 'Norrath', 'Tristram', 'Snowdin']
# 546
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Arbre', 'Faerun', 'Tristram', 'Norrath', 'Snowdin']
# 520
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Arbre', 'Norrath', 'Faerun', 'Tristram', 'Snowdin']
# 530
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Arbre', 'Norrath', 'Tristram', 'Faerun', 'Snowdin']
# 418
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Arbre', 'Tristram', 'Faerun', 'Norrath', 'Snowdin']
# 540
# ['AlphaCentauri', 'Tambi', 'Straylight', 'Arbre', 'Tristram', 'Norrath', 'Faerun', 'Snowdin']
# 454
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Faerun', 'Norrath', 'Straylight', 'Arbre', 'Snowdin']
# 344
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Faerun', 'Norrath', 'Arbre', 'Straylight', 'Snowdin']
# 445
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Faerun', 'Straylight', 'Norrath', 'Arbre', 'Snowdin']
# 281
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Faerun', 'Straylight', 'Arbre', 'Norrath', 'Snowdin']
# 373
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Faerun', 'Arbre', 'Norrath', 'Straylight', 'Snowdin']
# 393
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Faerun', 'Arbre', 'Straylight', 'Norrath', 'Snowdin']
# 384
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Norrath', 'Faerun', 'Straylight', 'Arbre', 'Snowdin']
# 349
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Norrath', 'Faerun', 'Arbre', 'Straylight', 'Snowdin']
# 461
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Norrath', 'Straylight', 'Faerun', 'Arbre', 'Snowdin']
# 297
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Norrath', 'Straylight', 'Arbre', 'Faerun', 'Snowdin']
# 298
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Norrath', 'Arbre', 'Faerun', 'Straylight', 'Snowdin']
# 398
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Norrath', 'Arbre', 'Straylight', 'Faerun', 'Snowdin']
# 287
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Straylight', 'Faerun', 'Norrath', 'Arbre', 'Snowdin']
# 305
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Straylight', 'Faerun', 'Arbre', 'Norrath', 'Snowdin']
# 345
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Straylight', 'Norrath', 'Faerun', 'Arbre', 'Snowdin']
# 316
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Straylight', 'Norrath', 'Arbre', 'Faerun', 'Snowdin']
# 254
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Straylight', 'Arbre', 'Faerun', 'Norrath', 'Snowdin']
# 408
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Straylight', 'Arbre', 'Norrath', 'Faerun', 'Snowdin']
# 306
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Arbre', 'Faerun', 'Norrath', 'Straylight', 'Snowdin']
# 429
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Arbre', 'Faerun', 'Straylight', 'Norrath', 'Snowdin']
# 357
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Arbre', 'Norrath', 'Faerun', 'Straylight', 'Snowdin']
# 418
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Arbre', 'Norrath', 'Straylight', 'Faerun', 'Snowdin']
# 255
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Arbre', 'Straylight', 'Faerun', 'Norrath', 'Snowdin']
# 409
# ['AlphaCentauri', 'Tambi', 'Tristram', 'Arbre', 'Straylight', 'Norrath', 'Faerun', 'Snowdin']
# 318
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Faerun', 'Norrath', 'Straylight', 'Tristram', 'Snowdin']
# 361
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Faerun', 'Norrath', 'Tristram', 'Straylight', 'Snowdin']
# 412
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Faerun', 'Straylight', 'Norrath', 'Tristram', 'Snowdin']
# 342
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Faerun', 'Straylight', 'Tristram', 'Norrath', 'Snowdin']
# 340
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Faerun', 'Tristram', 'Norrath', 'Straylight', 'Snowdin']
# 388
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Faerun', 'Tristram', 'Straylight', 'Norrath', 'Snowdin']
# 335
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Norrath', 'Faerun', 'Straylight', 'Tristram', 'Snowdin']
# 350
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Norrath', 'Faerun', 'Tristram', 'Straylight', 'Snowdin']
# 396
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Norrath', 'Straylight', 'Faerun', 'Tristram', 'Snowdin']
# 326
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Norrath', 'Straylight', 'Tristram', 'Faerun', 'Snowdin']
# 233
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Norrath', 'Tristram', 'Faerun', 'Straylight', 'Snowdin']
# 377
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Norrath', 'Tristram', 'Straylight', 'Faerun', 'Snowdin']
# 238
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Straylight', 'Faerun', 'Norrath', 'Tristram', 'Snowdin']
# 394
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Straylight', 'Faerun', 'Tristram', 'Norrath', 'Snowdin']
# 368
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Straylight', 'Norrath', 'Faerun', 'Tristram', 'Snowdin']
# 389
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Straylight', 'Norrath', 'Tristram', 'Faerun', 'Snowdin']
# 277
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Straylight', 'Tristram', 'Faerun', 'Norrath', 'Snowdin']
# 387
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Straylight', 'Tristram', 'Norrath', 'Faerun', 'Snowdin']
# 301
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Tristram', 'Faerun', 'Norrath', 'Straylight', 'Snowdin']
# 408
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Tristram', 'Faerun', 'Straylight', 'Norrath', 'Snowdin']
# 336
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Tristram', 'Norrath', 'Faerun', 'Straylight', 'Snowdin']
# 413
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Tristram', 'Norrath', 'Straylight', 'Faerun', 'Snowdin']
# 250
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Tristram', 'Straylight', 'Faerun', 'Norrath', 'Snowdin']
# 360
# ['AlphaCentauri', 'Tambi', 'Arbre', 'Tristram', 'Straylight', 'Norrath', 'Faerun', 'Snowdin']
# 269
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Norrath', 'Straylight', 'Tristram', 'Arbre', 'Snowdin']
# 409
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Norrath', 'Straylight', 'Arbre', 'Tristram', 'Snowdin']
# 503
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Norrath', 'Tristram', 'Straylight', 'Arbre', 'Snowdin']
# 441
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Norrath', 'Tristram', 'Arbre', 'Straylight', 'Snowdin']
# 554
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Norrath', 'Arbre', 'Straylight', 'Tristram', 'Snowdin']
# 491
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Norrath', 'Arbre', 'Tristram', 'Straylight', 'Snowdin']
# 510
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Straylight', 'Norrath', 'Tristram', 'Arbre', 'Snowdin']
# 449
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Straylight', 'Norrath', 'Arbre', 'Tristram', 'Snowdin']
# 499
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Straylight', 'Tristram', 'Norrath', 'Arbre', 'Snowdin']
# 437
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Straylight', 'Tristram', 'Arbre', 'Norrath', 'Snowdin']
# 497
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Straylight', 'Arbre', 'Norrath', 'Tristram', 'Snowdin']
# 531
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Straylight', 'Arbre', 'Tristram', 'Norrath', 'Snowdin']
# 541
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Tristram', 'Norrath', 'Straylight', 'Arbre', 'Snowdin']
# 345
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Tristram', 'Norrath', 'Arbre', 'Straylight', 'Snowdin']
# 446
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Tristram', 'Straylight', 'Norrath', 'Arbre', 'Snowdin']
# 301
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Tristram', 'Straylight', 'Arbre', 'Norrath', 'Snowdin']
# 393
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Tristram', 'Arbre', 'Norrath', 'Straylight', 'Snowdin']
# 414
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Tristram', 'Arbre', 'Straylight', 'Norrath', 'Snowdin']
# 405
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Arbre', 'Norrath', 'Straylight', 'Tristram', 'Snowdin']
# 346
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Arbre', 'Norrath', 'Tristram', 'Straylight', 'Snowdin']
# 397
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Arbre', 'Straylight', 'Norrath', 'Tristram', 'Snowdin']
# 390
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Arbre', 'Straylight', 'Tristram', 'Norrath', 'Snowdin']
# 388
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Arbre', 'Tristram', 'Norrath', 'Straylight', 'Snowdin']
# 409
# ['AlphaCentauri', 'Faerun', 'Tambi', 'Arbre', 'Tristram', 'Straylight', 'Norrath', 'Snowdin']
# 356
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Tambi', 'Straylight', 'Tristram', 'Arbre', 'Snowdin']
# 554
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Tambi', 'Straylight', 'Arbre', 'Tristram', 'Snowdin']
# 648
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Tambi', 'Tristram', 'Straylight', 'Arbre', 'Snowdin']
# 450
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Tambi', 'Tristram', 'Arbre', 'Straylight', 'Snowdin']
# 563
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Tambi', 'Arbre', 'Straylight', 'Tristram', 'Snowdin']
# 495
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Tambi', 'Arbre', 'Tristram', 'Straylight', 'Snowdin']
# 514
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Straylight', 'Tambi', 'Tristram', 'Arbre', 'Snowdin']
# 458
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Straylight', 'Tambi', 'Arbre', 'Tristram', 'Snowdin']
# 503
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Straylight', 'Tristram', 'Tambi', 'Arbre', 'Snowdin']
# 305
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Straylight', 'Tristram', 'Arbre', 'Tambi', 'Snowdin']
# 311
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Straylight', 'Arbre', 'Tambi', 'Tristram', 'Snowdin']
# 399
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Straylight', 'Arbre', 'Tristram', 'Tambi', 'Snowdin']
# 360
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Tristram', 'Tambi', 'Straylight', 'Arbre', 'Snowdin']
# 490
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Tristram', 'Tambi', 'Arbre', 'Straylight', 'Snowdin']
# 450
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Tristram', 'Straylight', 'Tambi', 'Arbre', 'Snowdin']
# 441
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Tristram', 'Straylight', 'Arbre', 'Tambi', 'Snowdin']
# 343
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Tristram', 'Arbre', 'Tambi', 'Straylight', 'Snowdin']
# 554
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Tristram', 'Arbre', 'Straylight', 'Tambi', 'Snowdin']
# 496
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Arbre', 'Tambi', 'Straylight', 'Tristram', 'Snowdin']
# 491
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Arbre', 'Tambi', 'Tristram', 'Straylight', 'Snowdin']
# 406
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Arbre', 'Straylight', 'Tambi', 'Tristram', 'Snowdin']
# 540
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Arbre', 'Straylight', 'Tristram', 'Tambi', 'Snowdin']
# 348
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Arbre', 'Tristram', 'Tambi', 'Straylight', 'Snowdin']
# 559
# ['AlphaCentauri', 'Faerun', 'Norrath', 'Arbre', 'Tristram', 'Straylight', 'Tambi', 'Snowdin']
# 452
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Tambi', 'Norrath', 'Tristram', 'Arbre', 'Snowdin']
# 535
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Tambi', 'Norrath', 'Arbre', 'Tristram', 'Snowdin']
# 585
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Tambi', 'Tristram', 'Norrath', 'Arbre', 'Snowdin']
# 427
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Tambi', 'Tristram', 'Arbre', 'Norrath', 'Snowdin']
# 487
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Tambi', 'Arbre', 'Norrath', 'Tristram', 'Snowdin']
# 472
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Tambi', 'Arbre', 'Tristram', 'Norrath', 'Snowdin']
# 482
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Norrath', 'Tambi', 'Tristram', 'Arbre', 'Snowdin']
# 399
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Norrath', 'Tambi', 'Arbre', 'Tristram', 'Snowdin']
# 444
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Norrath', 'Tristram', 'Tambi', 'Arbre', 'Snowdin']
# 286
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Norrath', 'Tristram', 'Arbre', 'Tambi', 'Snowdin']
# 292
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Norrath', 'Arbre', 'Tambi', 'Tristram', 'Snowdin']
# 336
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Norrath', 'Arbre', 'Tristram', 'Tambi', 'Snowdin']
# 297
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Tristram', 'Tambi', 'Norrath', 'Arbre', 'Snowdin']
# 387
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Tristram', 'Tambi', 'Arbre', 'Norrath', 'Snowdin']
# 334
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Tristram', 'Norrath', 'Tambi', 'Arbre', 'Snowdin']
# 382
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Tristram', 'Norrath', 'Arbre', 'Tambi', 'Snowdin']
# 280
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Tristram', 'Arbre', 'Tambi', 'Norrath', 'Snowdin']
# 442
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Tristram', 'Arbre', 'Norrath', 'Tambi', 'Snowdin']
# 393
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Arbre', 'Tambi', 'Norrath', 'Tristram', 'Snowdin']
# 476
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Arbre', 'Tambi', 'Tristram', 'Norrath', 'Snowdin']
# 378
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Arbre', 'Norrath', 'Tambi', 'Tristram', 'Snowdin']
# 481
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Arbre', 'Norrath', 'Tristram', 'Tambi', 'Snowdin']
# 329
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Arbre', 'Tristram', 'Tambi', 'Norrath', 'Snowdin']
# 491
# ['AlphaCentauri', 'Faerun', 'Straylight', 'Arbre', 'Tristram', 'Norrath', 'Tambi', 'Snowdin']
# 437
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Tambi', 'Norrath', 'Straylight', 'Arbre', 'Snowdin']
# 426
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Tambi', 'Norrath', 'Arbre', 'Straylight', 'Snowdin']
# 527
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Tambi', 'Straylight', 'Norrath', 'Arbre', 'Snowdin']
# 422
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Tambi', 'Straylight', 'Arbre', 'Norrath', 'Snowdin']
# 514
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Tambi', 'Arbre', 'Norrath', 'Straylight', 'Snowdin']
# 382
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Tambi', 'Arbre', 'Straylight', 'Norrath', 'Snowdin']
# 373
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Norrath', 'Tambi', 'Straylight', 'Arbre', 'Snowdin']
# 562
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Norrath', 'Tambi', 'Arbre', 'Straylight', 'Snowdin']
# 522
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Norrath', 'Straylight', 'Tambi', 'Arbre', 'Snowdin']
# 417
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Norrath', 'Straylight', 'Arbre', 'Tambi', 'Snowdin']
# 319
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Norrath', 'Arbre', 'Tambi', 'Straylight', 'Snowdin']
# 518
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Norrath', 'Arbre', 'Straylight', 'Tambi', 'Snowdin']
# 460
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Straylight', 'Tambi', 'Norrath', 'Arbre', 'Snowdin']
# 518
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Straylight', 'Tambi', 'Arbre', 'Norrath', 'Snowdin']
# 465
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Straylight', 'Norrath', 'Tambi', 'Arbre', 'Snowdin']
# 377
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Straylight', 'Norrath', 'Arbre', 'Tambi', 'Snowdin']
# 275
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Straylight', 'Arbre', 'Tambi', 'Norrath', 'Snowdin']
# 469
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Straylight', 'Arbre', 'Norrath', 'Tambi', 'Snowdin']
# 420
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Arbre', 'Tambi', 'Norrath', 'Straylight', 'Snowdin']
# 490
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Arbre', 'Tambi', 'Straylight', 'Norrath', 'Snowdin']
# 477
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Arbre', 'Norrath', 'Tambi', 'Straylight', 'Snowdin']
# 631
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Arbre', 'Norrath', 'Straylight', 'Tambi', 'Snowdin']
# 428
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Arbre', 'Straylight', 'Tambi', 'Norrath', 'Snowdin']
# 622
# ['AlphaCentauri', 'Faerun', 'Tristram', 'Arbre', 'Straylight', 'Norrath', 'Tambi', 'Snowdin']
# 432
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Tambi', 'Norrath', 'Straylight', 'Tristram', 'Snowdin']
# 443
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Tambi', 'Norrath', 'Tristram', 'Straylight', 'Snowdin']
# 494
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Tambi', 'Straylight', 'Norrath', 'Tristram', 'Snowdin']
# 483
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Tambi', 'Straylight', 'Tristram', 'Norrath', 'Snowdin']
# 481
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Tambi', 'Tristram', 'Norrath', 'Straylight', 'Snowdin']
# 398
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Tambi', 'Tristram', 'Straylight', 'Norrath', 'Snowdin']
# 345
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Norrath', 'Tambi', 'Straylight', 'Tristram', 'Snowdin']
# 584
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Norrath', 'Tambi', 'Tristram', 'Straylight', 'Snowdin']
# 499
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Norrath', 'Straylight', 'Tambi', 'Tristram', 'Snowdin']
# 488
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Norrath', 'Straylight', 'Tristram', 'Tambi', 'Snowdin']
# 296
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Norrath', 'Tristram', 'Tambi', 'Straylight', 'Snowdin']
# 539
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Norrath', 'Tristram', 'Straylight', 'Tambi', 'Snowdin']
# 432
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Straylight', 'Tambi', 'Norrath', 'Tristram', 'Snowdin']
# 628
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Straylight', 'Tambi', 'Tristram', 'Norrath', 'Snowdin']
# 530
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Straylight', 'Norrath', 'Tambi', 'Tristram', 'Snowdin']
# 492
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Straylight', 'Norrath', 'Tristram', 'Tambi', 'Snowdin']
# 340
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Straylight', 'Tristram', 'Tambi', 'Norrath', 'Snowdin']
# 490
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Straylight', 'Tristram', 'Norrath', 'Tambi', 'Snowdin']
# 436
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Tristram', 'Tambi', 'Norrath', 'Straylight', 'Snowdin']
# 511
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Tristram', 'Tambi', 'Straylight', 'Norrath', 'Snowdin']
# 498
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Tristram', 'Norrath', 'Tambi', 'Straylight', 'Snowdin']
# 647
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Tristram', 'Norrath', 'Straylight', 'Tambi', 'Snowdin']
# 444
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Tristram', 'Straylight', 'Tambi', 'Norrath', 'Snowdin']
# 594
# ['AlphaCentauri', 'Faerun', 'Arbre', 'Tristram', 'Straylight', 'Norrath', 'Tambi', 'Snowdin']
# 404
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Faerun', 'Straylight', 'Tristram', 'Arbre', 'Snowdin']
# 395
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Faerun', 'Straylight', 'Arbre', 'Tristram', 'Snowdin']
# 489
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Faerun', 'Tristram', 'Straylight', 'Arbre', 'Snowdin']
# 422
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Faerun', 'Tristram', 'Arbre', 'Straylight', 'Snowdin']
# 535
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Faerun', 'Arbre', 'Straylight', 'Tristram', 'Snowdin']
# 488
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Faerun', 'Arbre', 'Tristram', 'Straylight', 'Snowdin']
# 507
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Straylight', 'Faerun', 'Tristram', 'Arbre', 'Snowdin']
# 516
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Straylight', 'Faerun', 'Arbre', 'Tristram', 'Snowdin']
# 582
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Straylight', 'Tristram', 'Faerun', 'Arbre', 'Snowdin']
# 515
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Straylight', 'Tristram', 'Arbre', 'Faerun', 'Snowdin']
# 489
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Straylight', 'Arbre', 'Faerun', 'Tristram', 'Snowdin']
# 609
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Straylight', 'Arbre', 'Tristram', 'Faerun', 'Snowdin']
# 517
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Tristram', 'Faerun', 'Straylight', 'Arbre', 'Snowdin']
# 412
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Tristram', 'Faerun', 'Arbre', 'Straylight', 'Snowdin']
# 524
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Tristram', 'Straylight', 'Faerun', 'Arbre', 'Snowdin']
# 384
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Tristram', 'Straylight', 'Arbre', 'Faerun', 'Snowdin']
# 385
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Tristram', 'Arbre', 'Faerun', 'Straylight', 'Snowdin']
# 497
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Tristram', 'Arbre', 'Straylight', 'Faerun', 'Snowdin']
# 386
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Arbre', 'Faerun', 'Straylight', 'Tristram', 'Snowdin']
# 429
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Arbre', 'Faerun', 'Tristram', 'Straylight', 'Snowdin']
# 475
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Arbre', 'Straylight', 'Faerun', 'Tristram', 'Snowdin']
# 457
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Arbre', 'Straylight', 'Tristram', 'Faerun', 'Snowdin']
# 364
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Arbre', 'Tristram', 'Faerun', 'Straylight', 'Snowdin']
# 476
# ['AlphaCentauri', 'Norrath', 'Tambi', 'Arbre', 'Tristram', 'Straylight', 'Faerun', 'Snowdin']
# 337
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Tambi', 'Straylight', 'Tristram', 'Arbre', 'Snowdin']
# 454
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Tambi', 'Straylight', 'Arbre', 'Tristram', 'Snowdin']
# 548
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Tambi', 'Tristram', 'Straylight', 'Arbre', 'Snowdin']
# 350
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Tambi', 'Tristram', 'Arbre', 'Straylight', 'Snowdin']
# 463
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Tambi', 'Arbre', 'Straylight', 'Tristram', 'Snowdin']
# 395
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Tambi', 'Arbre', 'Tristram', 'Straylight', 'Snowdin']
# 414
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Straylight', 'Tambi', 'Tristram', 'Arbre', 'Snowdin']
# 444
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Straylight', 'Tambi', 'Arbre', 'Tristram', 'Snowdin']
# 489
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Straylight', 'Tristram', 'Tambi', 'Arbre', 'Snowdin']
# 291
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Straylight', 'Tristram', 'Arbre', 'Tambi', 'Snowdin']
# 297
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Straylight', 'Arbre', 'Tambi', 'Tristram', 'Snowdin']
# 385
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Straylight', 'Arbre', 'Tristram', 'Tambi', 'Snowdin']
# 346
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Tristram', 'Tambi', 'Straylight', 'Arbre', 'Snowdin']
# 471
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Tristram', 'Tambi', 'Arbre', 'Straylight', 'Snowdin']
# 431
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Tristram', 'Straylight', 'Tambi', 'Arbre', 'Snowdin']
# 422
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Tristram', 'Straylight', 'Arbre', 'Tambi', 'Snowdin']
# 324
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Tristram', 'Arbre', 'Tambi', 'Straylight', 'Snowdin']
# 535
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Tristram', 'Arbre', 'Straylight', 'Tambi', 'Snowdin']
# 477
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Arbre', 'Tambi', 'Straylight', 'Tristram', 'Snowdin']
# 488
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Arbre', 'Tambi', 'Tristram', 'Straylight', 'Snowdin']
# 403
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Arbre', 'Straylight', 'Tambi', 'Tristram', 'Snowdin']
# 537
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Arbre', 'Straylight', 'Tristram', 'Tambi', 'Snowdin']
# 345
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Arbre', 'Tristram', 'Tambi', 'Straylight', 'Snowdin']
# 556
# ['AlphaCentauri', 'Norrath', 'Faerun', 'Arbre', 'Tristram', 'Straylight', 'Tambi', 'Snowdin']
# 449
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Tambi', 'Faerun', 'Tristram', 'Arbre', 'Snowdin']
# 430
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Tambi', 'Faerun', 'Arbre', 'Tristram', 'Snowdin']
# 496
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Tambi', 'Tristram', 'Faerun', 'Arbre', 'Snowdin']
# 419
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Tambi', 'Tristram', 'Arbre', 'Faerun', 'Snowdin']
# 393
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Tambi', 'Arbre', 'Faerun', 'Tristram', 'Snowdin']
# 464
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Tambi', 'Arbre', 'Tristram', 'Faerun', 'Snowdin']
# 372
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Faerun', 'Tambi', 'Tristram', 'Arbre', 'Snowdin']
# 299
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Faerun', 'Tambi', 'Arbre', 'Tristram', 'Snowdin']
# 344
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Faerun', 'Tristram', 'Tambi', 'Arbre', 'Snowdin']
# 267
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Faerun', 'Tristram', 'Arbre', 'Tambi', 'Snowdin']
# 273
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Faerun', 'Arbre', 'Tambi', 'Tristram', 'Snowdin']
# 333
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Faerun', 'Arbre', 'Tristram', 'Tambi', 'Snowdin']
# 294
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Tristram', 'Tambi', 'Faerun', 'Arbre', 'Snowdin']
# 298
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Tristram', 'Tambi', 'Arbre', 'Faerun', 'Snowdin']
# 240
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Tristram', 'Faerun', 'Tambi', 'Arbre', 'Snowdin']
# 277
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Tristram', 'Faerun', 'Arbre', 'Tambi', 'Snowdin']
# 272
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Tristram', 'Arbre', 'Tambi', 'Faerun', 'Snowdin']
# 251
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Tristram', 'Arbre', 'Faerun', 'Tambi', 'Snowdin']
# 304
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Arbre', 'Tambi', 'Faerun', 'Tristram', 'Snowdin']
# 371
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Arbre', 'Tambi', 'Tristram', 'Faerun', 'Snowdin']
# 268
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Arbre', 'Faerun', 'Tambi', 'Tristram', 'Snowdin']
# 392
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Arbre', 'Faerun', 'Tristram', 'Tambi', 'Snowdin']
# 321
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Arbre', 'Tristram', 'Tambi', 'Faerun', 'Snowdin']
# 300
# ['AlphaCentauri', 'Norrath', 'Straylight', 'Arbre', 'Tristram', 'Faerun', 'Tambi', 'Snowdin']
# 332
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Tambi', 'Faerun', 'Straylight', 'Arbre', 'Snowdin']
# 331
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Tambi', 'Faerun', 'Arbre', 'Straylight', 'Snowdin']
# 443
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Tambi', 'Straylight', 'Faerun', 'Arbre', 'Snowdin']
# 424
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Tambi', 'Straylight', 'Arbre', 'Faerun', 'Snowdin']
# 425
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Tambi', 'Arbre', 'Faerun', 'Straylight', 'Snowdin']
# 384
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Tambi', 'Arbre', 'Straylight', 'Faerun', 'Snowdin']
# 273
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Faerun', 'Tambi', 'Straylight', 'Arbre', 'Snowdin']
# 462
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Faerun', 'Tambi', 'Arbre', 'Straylight', 'Snowdin']
# 422
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Faerun', 'Straylight', 'Tambi', 'Arbre', 'Snowdin']
# 403
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Faerun', 'Straylight', 'Arbre', 'Tambi', 'Snowdin']
# 305
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Faerun', 'Arbre', 'Tambi', 'Straylight', 'Snowdin']
# 515
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Faerun', 'Arbre', 'Straylight', 'Tambi', 'Snowdin']
# 457
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Straylight', 'Tambi', 'Faerun', 'Arbre', 'Snowdin']
# 434
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Straylight', 'Tambi', 'Arbre', 'Faerun', 'Snowdin']
# 376
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Straylight', 'Faerun', 'Tambi', 'Arbre', 'Snowdin']
# 282
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Straylight', 'Faerun', 'Arbre', 'Tambi', 'Snowdin']
# 277
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Straylight', 'Arbre', 'Tambi', 'Faerun', 'Snowdin']
# 283
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Straylight', 'Arbre', 'Faerun', 'Tambi', 'Snowdin']
# 336
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Arbre', 'Tambi', 'Faerun', 'Straylight', 'Snowdin']
# 395
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Arbre', 'Tambi', 'Straylight', 'Faerun', 'Snowdin']
# 377
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Arbre', 'Faerun', 'Tambi', 'Straylight', 'Snowdin']
# 547
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Arbre', 'Faerun', 'Straylight', 'Tambi', 'Snowdin']
# 430
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Arbre', 'Straylight', 'Tambi', 'Faerun', 'Snowdin']
# 436
# ['AlphaCentauri', 'Norrath', 'Tristram', 'Arbre', 'Straylight', 'Faerun', 'Tambi', 'Snowdin']
# 337
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Tambi', 'Faerun', 'Straylight', 'Tristram', 'Snowdin']
# 332
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Tambi', 'Faerun', 'Tristram', 'Straylight', 'Snowdin']
# 378
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Tambi', 'Straylight', 'Faerun', 'Tristram', 'Snowdin']
# 453
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Tambi', 'Straylight', 'Tristram', 'Faerun', 'Snowdin']
# 360
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Tambi', 'Tristram', 'Faerun', 'Straylight', 'Snowdin']
# 368
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Tambi', 'Tristram', 'Straylight', 'Faerun', 'Snowdin']
# 229
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Faerun', 'Tambi', 'Straylight', 'Tristram', 'Snowdin']
# 484
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Faerun', 'Tambi', 'Tristram', 'Straylight', 'Snowdin']
# 399
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Faerun', 'Straylight', 'Tambi', 'Tristram', 'Snowdin']
# 474
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Faerun', 'Straylight', 'Tristram', 'Tambi', 'Snowdin']
# 282
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Faerun', 'Tristram', 'Tambi', 'Straylight', 'Snowdin']
# 520
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Faerun', 'Tristram', 'Straylight', 'Tambi', 'Snowdin']
# 413
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Straylight', 'Tambi', 'Faerun', 'Tristram', 'Snowdin']
# 512
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Straylight', 'Tambi', 'Tristram', 'Faerun', 'Snowdin']
# 409
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Straylight', 'Faerun', 'Tambi', 'Tristram', 'Snowdin']
# 381
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Straylight', 'Faerun', 'Tristram', 'Tambi', 'Snowdin']
# 310
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Straylight', 'Tristram', 'Tambi', 'Faerun', 'Snowdin']
# 288
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Straylight', 'Tristram', 'Faerun', 'Tambi', 'Snowdin']
# 320
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Tristram', 'Tambi', 'Faerun', 'Straylight', 'Snowdin']
# 400
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Tristram', 'Tambi', 'Straylight', 'Faerun', 'Snowdin']
# 382
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Tristram', 'Faerun', 'Tambi', 'Straylight', 'Snowdin']
# 531
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Tristram', 'Faerun', 'Straylight', 'Tambi', 'Snowdin']
# 414
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Tristram', 'Straylight', 'Tambi', 'Faerun', 'Snowdin']
# 392
# ['AlphaCentauri', 'Norrath', 'Arbre', 'Tristram', 'Straylight', 'Faerun', 'Tambi', 'Snowdin']
# 293
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Faerun', 'Norrath', 'Tristram', 'Arbre', 'Snowdin']
# 477
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Faerun', 'Norrath', 'Arbre', 'Tristram', 'Snowdin']
# 527
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Faerun', 'Tristram', 'Norrath', 'Arbre', 'Snowdin']
# 441
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Faerun', 'Tristram', 'Arbre', 'Norrath', 'Snowdin']
# 501
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Faerun', 'Arbre', 'Norrath', 'Tristram', 'Snowdin']
# 507
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Faerun', 'Arbre', 'Tristram', 'Norrath', 'Snowdin']
# 517
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Norrath', 'Faerun', 'Tristram', 'Arbre', 'Snowdin']
# 558
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Norrath', 'Faerun', 'Arbre', 'Tristram', 'Snowdin']
# 624
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Norrath', 'Tristram', 'Faerun', 'Arbre', 'Snowdin']
# 538
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Norrath', 'Tristram', 'Arbre', 'Faerun', 'Snowdin']
# 512
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Norrath', 'Arbre', 'Faerun', 'Tristram', 'Snowdin']
# 588
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Norrath', 'Arbre', 'Tristram', 'Faerun', 'Snowdin']
# 496
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Tristram', 'Faerun', 'Norrath', 'Arbre', 'Snowdin']
# 450
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Tristram', 'Faerun', 'Arbre', 'Norrath', 'Snowdin']
# 490
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Tristram', 'Norrath', 'Faerun', 'Arbre', 'Snowdin']
# 466
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Tristram', 'Norrath', 'Arbre', 'Faerun', 'Snowdin']
# 404
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Tristram', 'Arbre', 'Faerun', 'Norrath', 'Snowdin']
# 526
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Tristram', 'Arbre', 'Norrath', 'Faerun', 'Snowdin']
# 424
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Arbre', 'Faerun', 'Norrath', 'Tristram', 'Snowdin']
# 511
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Arbre', 'Faerun', 'Tristram', 'Norrath', 'Snowdin']
# 485
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Arbre', 'Norrath', 'Faerun', 'Tristram', 'Snowdin']
# 495
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Arbre', 'Norrath', 'Tristram', 'Faerun', 'Snowdin']
# 383
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Arbre', 'Tristram', 'Faerun', 'Norrath', 'Snowdin']
# 505
# ['AlphaCentauri', 'Straylight', 'Tambi', 'Arbre', 'Tristram', 'Norrath', 'Faerun', 'Snowdin']
# 419
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Tambi', 'Norrath', 'Tristram', 'Arbre', 'Snowdin']
# 418
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Tambi', 'Norrath', 'Arbre', 'Tristram', 'Snowdin']
# 468
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Tambi', 'Tristram', 'Norrath', 'Arbre', 'Snowdin']
# 310
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Tambi', 'Tristram', 'Arbre', 'Norrath', 'Snowdin']
# 370
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Tambi', 'Arbre', 'Norrath', 'Tristram', 'Snowdin']
# 355
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Tambi', 'Arbre', 'Tristram', 'Norrath', 'Snowdin']
# 365
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Norrath', 'Tambi', 'Tristram', 'Arbre', 'Snowdin']
# 427
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Norrath', 'Tambi', 'Arbre', 'Tristram', 'Snowdin']
# 472
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Norrath', 'Tristram', 'Tambi', 'Arbre', 'Snowdin']
# 314
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Norrath', 'Tristram', 'Arbre', 'Tambi', 'Snowdin']
# 320
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Norrath', 'Arbre', 'Tambi', 'Tristram', 'Snowdin']
# 364
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Norrath', 'Arbre', 'Tristram', 'Tambi', 'Snowdin']
# 325
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Tristram', 'Tambi', 'Norrath', 'Arbre', 'Snowdin']
# 391
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Tristram', 'Tambi', 'Arbre', 'Norrath', 'Snowdin']
# 338
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Tristram', 'Norrath', 'Tambi', 'Arbre', 'Snowdin']
# 386
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Tristram', 'Norrath', 'Arbre', 'Tambi', 'Snowdin']
# 284
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Tristram', 'Arbre', 'Tambi', 'Norrath', 'Snowdin']
# 446
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Tristram', 'Arbre', 'Norrath', 'Tambi', 'Snowdin']
# 397
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Arbre', 'Tambi', 'Norrath', 'Tristram', 'Snowdin']
# 452
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Arbre', 'Tambi', 'Tristram', 'Norrath', 'Snowdin']
# 354
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Arbre', 'Norrath', 'Tambi', 'Tristram', 'Snowdin']
# 457
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Arbre', 'Norrath', 'Tristram', 'Tambi', 'Snowdin']
# 305
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Arbre', 'Tristram', 'Tambi', 'Norrath', 'Snowdin']
# 467
# ['AlphaCentauri', 'Straylight', 'Faerun', 'Arbre', 'Tristram', 'Norrath', 'Tambi', 'Snowdin']
# 413
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Tambi', 'Faerun', 'Tristram', 'Arbre', 'Snowdin']
# 413
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Tambi', 'Faerun', 'Arbre', 'Tristram', 'Snowdin']
# 479
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Tambi', 'Tristram', 'Faerun', 'Arbre', 'Snowdin']
# 402
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Tambi', 'Tristram', 'Arbre', 'Faerun', 'Snowdin']
# 376
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Tambi', 'Arbre', 'Faerun', 'Tristram', 'Snowdin']
# 447
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Tambi', 'Arbre', 'Tristram', 'Faerun', 'Snowdin']
# 355
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Faerun', 'Tambi', 'Tristram', 'Arbre', 'Snowdin']
# 341
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Faerun', 'Tambi', 'Arbre', 'Tristram', 'Snowdin']
# 386
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Faerun', 'Tristram', 'Tambi', 'Arbre', 'Snowdin']
# 309
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Faerun', 'Tristram', 'Arbre', 'Tambi', 'Snowdin']
# 315
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Faerun', 'Arbre', 'Tambi', 'Tristram', 'Snowdin']
# 375
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Faerun', 'Arbre', 'Tristram', 'Tambi', 'Snowdin']
# 336
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Tristram', 'Tambi', 'Faerun', 'Arbre', 'Snowdin']
# 321
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Tristram', 'Tambi', 'Arbre', 'Faerun', 'Snowdin']
# 263
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Tristram', 'Faerun', 'Tambi', 'Arbre', 'Snowdin']
# 300
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Tristram', 'Faerun', 'Arbre', 'Tambi', 'Snowdin']
# 295
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Tristram', 'Arbre', 'Tambi', 'Faerun', 'Snowdin']
# 274
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Tristram', 'Arbre', 'Faerun', 'Tambi', 'Snowdin']
# 327
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Arbre', 'Tambi', 'Faerun', 'Tristram', 'Snowdin']
# 350
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Arbre', 'Tambi', 'Tristram', 'Faerun', 'Snowdin']
# 247
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Arbre', 'Faerun', 'Tambi', 'Tristram', 'Snowdin']
# 371
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Arbre', 'Faerun', 'Tristram', 'Tambi', 'Snowdin']
# 300
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Arbre', 'Tristram', 'Tambi', 'Faerun', 'Snowdin']
# 279
# ['AlphaCentauri', 'Straylight', 'Norrath', 'Arbre', 'Tristram', 'Faerun', 'Tambi', 'Snowdin']
# 311
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Tambi', 'Faerun', 'Norrath', 'Arbre', 'Snowdin']
# 329
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Tambi', 'Faerun', 'Arbre', 'Norrath', 'Snowdin']
# 369
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Tambi', 'Norrath', 'Faerun', 'Arbre', 'Snowdin']
# 426
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Tambi', 'Norrath', 'Arbre', 'Faerun', 'Snowdin']
# 364
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Tambi', 'Arbre', 'Faerun', 'Norrath', 'Snowdin']
# 373
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Tambi', 'Arbre', 'Norrath', 'Faerun', 'Snowdin']
# 271
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Faerun', 'Tambi', 'Norrath', 'Arbre', 'Snowdin']
# 401
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Faerun', 'Tambi', 'Arbre', 'Norrath', 'Snowdin']
# 348
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Faerun', 'Norrath', 'Tambi', 'Arbre', 'Snowdin']
# 405
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Faerun', 'Norrath', 'Arbre', 'Tambi', 'Snowdin']
# 303
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Faerun', 'Arbre', 'Tambi', 'Norrath', 'Snowdin']
# 445
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Faerun', 'Arbre', 'Norrath', 'Tambi', 'Snowdin']
# 396
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Norrath', 'Tambi', 'Faerun', 'Arbre', 'Snowdin']
# 417
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Norrath', 'Tambi', 'Arbre', 'Faerun', 'Snowdin']
# 359
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Norrath', 'Faerun', 'Tambi', 'Arbre', 'Snowdin']
# 324
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Norrath', 'Faerun', 'Arbre', 'Tambi', 'Snowdin']
# 319
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Norrath', 'Arbre', 'Tambi', 'Faerun', 'Snowdin']
# 262
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Norrath', 'Arbre', 'Faerun', 'Tambi', 'Snowdin']
# 315
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Arbre', 'Tambi', 'Faerun', 'Norrath', 'Snowdin']
# 384
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Arbre', 'Tambi', 'Norrath', 'Faerun', 'Snowdin']
# 379
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Arbre', 'Faerun', 'Tambi', 'Norrath', 'Snowdin']
# 477
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Arbre', 'Faerun', 'Norrath', 'Tambi', 'Snowdin']
# 432
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Arbre', 'Norrath', 'Tambi', 'Faerun', 'Snowdin']
# 375
# ['AlphaCentauri', 'Straylight', 'Tristram', 'Arbre', 'Norrath', 'Faerun', 'Tambi', 'Snowdin']
# 335
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Tambi', 'Faerun', 'Norrath', 'Tristram', 'Snowdin']
# 418
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Tambi', 'Faerun', 'Tristram', 'Norrath', 'Snowdin']
# 392
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Tambi', 'Norrath', 'Faerun', 'Tristram', 'Snowdin']
# 499
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Tambi', 'Norrath', 'Tristram', 'Faerun', 'Snowdin']
# 387
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Tambi', 'Tristram', 'Faerun', 'Norrath', 'Snowdin']
# 401
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Tambi', 'Tristram', 'Norrath', 'Faerun', 'Snowdin']
# 315
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Faerun', 'Tambi', 'Norrath', 'Tristram', 'Snowdin']
# 511
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Faerun', 'Tambi', 'Tristram', 'Norrath', 'Snowdin']
# 413
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Faerun', 'Norrath', 'Tambi', 'Tristram', 'Snowdin']
# 520
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Faerun', 'Norrath', 'Tristram', 'Tambi', 'Snowdin']
# 368
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Faerun', 'Tristram', 'Tambi', 'Norrath', 'Snowdin']
# 494
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Faerun', 'Tristram', 'Norrath', 'Tambi', 'Snowdin']
# 440
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Norrath', 'Tambi', 'Faerun', 'Tristram', 'Snowdin']
# 495
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Norrath', 'Tambi', 'Tristram', 'Faerun', 'Snowdin']
# 392
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Norrath', 'Faerun', 'Tambi', 'Tristram', 'Snowdin']
# 423
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Norrath', 'Faerun', 'Tristram', 'Tambi', 'Snowdin']
# 352
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Norrath', 'Tristram', 'Tambi', 'Faerun', 'Snowdin']
# 311
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Norrath', 'Tristram', 'Faerun', 'Tambi', 'Snowdin']
# 343
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Tristram', 'Tambi', 'Faerun', 'Norrath', 'Snowdin']
# 433
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Tristram', 'Tambi', 'Norrath', 'Faerun', 'Snowdin']
# 428
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Tristram', 'Faerun', 'Tambi', 'Norrath', 'Snowdin']
# 505
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Tristram', 'Faerun', 'Norrath', 'Tambi', 'Snowdin']
# 460
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Tristram', 'Norrath', 'Tambi', 'Faerun', 'Snowdin']
# 419
# ['AlphaCentauri', 'Straylight', 'Arbre', 'Tristram', 'Norrath', 'Faerun', 'Tambi', 'Snowdin']
# 379
# ['AlphaCentauri', 'Tristram', 'Tambi', 'Faerun', 'Norrath', 'Straylight', 'Arbre', 'Snowdin']
# 301
# ['AlphaCentauri', 'Tristram', 'Tambi', 'Faerun', 'Norrath', 'Arbre', 'Straylight', 'Snowdin']
# 402
# ['AlphaCentauri', 'Tristram', 'Tambi', 'Faerun', 'Straylight', 'Norrath', 'Arbre', 'Snowdin']
# 238
# ['AlphaCentauri', 'Tristram', 'Tambi', 'Faerun', 'Straylight', 'Arbre', 'Norrath', 'Snowdin']
# 330
# ['AlphaCentauri', 'Tristram', 'Tambi', 'Faerun', 'Arbre', 'Norrath', 'Straylight', 'Snowdin']
# 350
# ['AlphaCentauri', 'Tristram', 'Tambi', 'Faerun', 'Arbre', 'Straylight', 'Norrath', 'Snowdin']
# 341
# ['AlphaCentauri', 'Tristram', 'Tambi', 'Norrath', 'Faerun', 'Straylight', 'Arbre', 'Snowdin']
# 387
# ['AlphaCentauri', 'Tristram', 'Tambi', 'Norrath', 'Faerun', 'Arbre', 'Straylight', 'Snowdin']
# 499
# ['AlphaCentauri', 'Tristram', 'Tambi', 'Norrath', 'Straylight', 'Faerun', 'Arbre', 'Snowdin']
# 335
# ...
# 430
# ['Tristram', 'Norrath', 'Faerun', 'Snowdin', 'AlphaCentauri', 'Tambi', 'Straylight', 'Arbre']
# 430
# ['Tristram', 'Norrath', 'Faerun', 'Snowdin', 'AlphaCentauri', 'Straylight', 'Tambi', 'Arbre']
# 395
# ['Tristram', 'Norrath', 'Faerun', 'Snowdin', 'Tambi', 'AlphaCentauri', 'Straylight', 'Arbre']
# 290
# ['Tristram', 'Norrath', 'Faerun', 'Snowdin', 'Tambi', 'Straylight', 'AlphaCentauri', 'Arbre']
# 419
# ['Tristram', 'Norrath', 'Faerun', 'Snowdin', 'Straylight', 'AlphaCentauri', 'Tambi', 'Arbre']
# 348
# ['Tristram', 'Norrath', 'Faerun', 'Snowdin', 'Straylight', 'Tambi', 'AlphaCentauri', 'Arbre']
# 512
# ['Tristram', 'Norrath', 'Faerun', 'Tambi', 'AlphaCentauri', 'Snowdin', 'Straylight', 'Arbre']
# 448
# ['Tristram', 'Norrath', 'Faerun', 'Tambi', 'AlphaCentauri', 'Straylight', 'Snowdin', 'Arbre']
# 406
# ['Tristram', 'Norrath', 'Faerun', 'Tambi', 'Snowdin', 'AlphaCentauri', 'Straylight', 'Arbre']
# 355
# ['Tristram', 'Norrath', 'Faerun', 'Tambi', 'Snowdin', 'Straylight', 'AlphaCentauri', 'Arbre']
# 437
# ['Tristram', 'Norrath', 'Faerun', 'Tambi', 'Straylight', 'AlphaCentauri', 'Snowdin', 'Arbre']
# 453
# ['Tristram', 'Norrath', 'Faerun', 'Tambi', 'Straylight', 'Snowdin', 'AlphaCentauri', 'Arbre']
# 577
# ['Tristram', 'Norrath', 'Faerun', 'Straylight', 'AlphaCentauri', 'Snowdin', 'Tambi', 'Arbre']
# 296
# ['Tristram', 'Norrath', 'Faerun', 'Straylight', 'AlphaCentauri', 'Tambi', 'Snowdin', 'Arbre']
# 289
# ['Tristram', 'Norrath', 'Faerun', 'Straylight', 'Snowdin', 'AlphaCentauri', 'Tambi', 'Arbre']
# 389
# ['Tristram', 'Norrath', 'Faerun', 'Straylight', 'Snowdin', 'Tambi', 'AlphaCentauri', 'Arbre']
# 413
# ['Tristram', 'Norrath', 'Faerun', 'Straylight', 'Tambi', 'AlphaCentauri', 'Snowdin', 'Arbre']
# 429
# ['Tristram', 'Norrath', 'Faerun', 'Straylight', 'Tambi', 'Snowdin', 'AlphaCentauri', 'Arbre']
# 460
# ['Tristram', 'Norrath', 'Straylight', 'AlphaCentauri', 'Snowdin', 'Tambi', 'Faerun', 'Arbre']
# 303
# ['Tristram', 'Norrath', 'Straylight', 'AlphaCentauri', 'Snowdin', 'Faerun', 'Tambi', 'Arbre']
# 250
# ['Tristram', 'Norrath', 'Straylight', 'AlphaCentauri', 'Tambi', 'Snowdin', 'Faerun', 'Arbre']
# 238
# ['Tristram', 'Norrath', 'Straylight', 'AlphaCentauri', 'Tambi', 'Faerun', 'Snowdin', 'Arbre']
# 243
# ['Tristram', 'Norrath', 'Straylight', 'AlphaCentauri', 'Faerun', 'Snowdin', 'Tambi', 'Arbre']
# 227
# ['Tristram', 'Norrath', 'Straylight', 'AlphaCentauri', 'Faerun', 'Tambi', 'Snowdin', 'Arbre']
# 285
# ['Tristram', 'Norrath', 'Straylight', 'Snowdin', 'AlphaCentauri', 'Tambi', 'Faerun', 'Arbre']
# 396
# ['Tristram', 'Norrath', 'Straylight', 'Snowdin', 'AlphaCentauri', 'Faerun', 'Tambi', 'Arbre']
# 385
# ['Tristram', 'Norrath', 'Straylight', 'Snowdin', 'Tambi', 'AlphaCentauri', 'Faerun', 'Arbre']
# 373
# ['Tristram', 'Norrath', 'Straylight', 'Snowdin', 'Tambi', 'Faerun', 'AlphaCentauri', 'Arbre']
# 409
# ['Tristram', 'Norrath', 'Straylight', 'Snowdin', 'Faerun', 'AlphaCentauri', 'Tambi', 'Arbre']
# 320
# ['Tristram', 'Norrath', 'Straylight', 'Snowdin', 'Faerun', 'Tambi', 'AlphaCentauri', 'Arbre']
# 367
# ['Tristram', 'Norrath', 'Straylight', 'Tambi', 'AlphaCentauri', 'Snowdin', 'Faerun', 'Arbre']
# 378
# ['Tristram', 'Norrath', 'Straylight', 'Tambi', 'AlphaCentauri', 'Faerun', 'Snowdin', 'Arbre']
# 360
# ['Tristram', 'Norrath', 'Straylight', 'Tambi', 'Snowdin', 'AlphaCentauri', 'Faerun', 'Arbre']
# 420
# ['Tristram', 'Norrath', 'Straylight', 'Tambi', 'Snowdin', 'Faerun', 'AlphaCentauri', 'Arbre']
# 391
# ['Tristram', 'Norrath', 'Straylight', 'Tambi', 'Faerun', 'AlphaCentauri', 'Snowdin', 'Arbre']
# 425
# ['Tristram', 'Norrath', 'Straylight', 'Tambi', 'Faerun', 'Snowdin', 'AlphaCentauri', 'Arbre']
# 414
# ['Tristram', 'Norrath', 'Straylight', 'Faerun', 'AlphaCentauri', 'Snowdin', 'Tambi', 'Arbre']
# 268
# ['Tristram', 'Norrath', 'Straylight', 'Faerun', 'AlphaCentauri', 'Tambi', 'Snowdin', 'Arbre']
# 261
# ['Tristram', 'Norrath', 'Straylight', 'Faerun', 'Snowdin', 'AlphaCentauri', 'Tambi', 'Arbre']
# 226
# ['Tristram', 'Norrath', 'Straylight', 'Faerun', 'Snowdin', 'Tambi', 'AlphaCentauri', 'Arbre']
# 250
# ['Tristram', 'Norrath', 'Straylight', 'Faerun', 'Tambi', 'AlphaCentauri', 'Snowdin', 'Arbre']
# 284
# ['Tristram', 'Norrath', 'Straylight', 'Faerun', 'Tambi', 'Snowdin', 'AlphaCentauri', 'Arbre']
# 315
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Snowdin', 'Tambi', 'Faerun', 'Norrath', 'Arbre']
# 311
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Snowdin', 'Tambi', 'Norrath', 'Faerun', 'Arbre']
# 408
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Snowdin', 'Faerun', 'Tambi', 'Norrath', 'Arbre']
# 351
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Snowdin', 'Faerun', 'Norrath', 'Tambi', 'Arbre']
# 355
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Snowdin', 'Norrath', 'Tambi', 'Faerun', 'Arbre']
# 453
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Snowdin', 'Norrath', 'Faerun', 'Tambi', 'Arbre']
# 360
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Tambi', 'Snowdin', 'Faerun', 'Norrath', 'Arbre']
# 246
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Tambi', 'Snowdin', 'Norrath', 'Faerun', 'Arbre']
# 348
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Tambi', 'Faerun', 'Snowdin', 'Norrath', 'Arbre']
# 291
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Tambi', 'Faerun', 'Norrath', 'Snowdin', 'Arbre']
# 353
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Tambi', 'Norrath', 'Snowdin', 'Faerun', 'Arbre']
# 388
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Tambi', 'Norrath', 'Faerun', 'Snowdin', 'Arbre']
# 348
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Faerun', 'Snowdin', 'Tambi', 'Norrath', 'Arbre']
# 328
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Faerun', 'Snowdin', 'Norrath', 'Tambi', 'Arbre']
# 377
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Faerun', 'Tambi', 'Snowdin', 'Norrath', 'Arbre']
# 333
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Faerun', 'Tambi', 'Norrath', 'Snowdin', 'Arbre']
# 435
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Faerun', 'Norrath', 'Snowdin', 'Tambi', 'Arbre']
# 337
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Faerun', 'Norrath', 'Tambi', 'Snowdin', 'Arbre']
# 390
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Norrath', 'Snowdin', 'Tambi', 'Faerun', 'Arbre']
# 330
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Norrath', 'Snowdin', 'Faerun', 'Tambi', 'Arbre']
# 277
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Norrath', 'Tambi', 'Snowdin', 'Faerun', 'Arbre']
# 325
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Norrath', 'Tambi', 'Faerun', 'Snowdin', 'Arbre']
# 330
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Norrath', 'Faerun', 'Snowdin', 'Tambi', 'Arbre']
# 232
# ['Tristram', 'Straylight', 'AlphaCentauri', 'Norrath', 'Faerun', 'Tambi', 'Snowdin', 'Arbre']
# 290
# ['Tristram', 'Straylight', 'Snowdin', 'AlphaCentauri', 'Tambi', 'Faerun', 'Norrath', 'Arbre']
# 404
# ['Tristram', 'Straylight', 'Snowdin', 'AlphaCentauri', 'Tambi', 'Norrath', 'Faerun', 'Arbre']
# 501
# ['Tristram', 'Straylight', 'Snowdin', 'AlphaCentauri', 'Faerun', 'Tambi', 'Norrath', 'Arbre']
# 486
# ['Tristram', 'Straylight', 'Snowdin', 'AlphaCentauri', 'Faerun', 'Norrath', 'Tambi', 'Arbre']
# 490
# ['Tristram', 'Straylight', 'Snowdin', 'AlphaCentauri', 'Norrath', 'Tambi', 'Faerun', 'Arbre']
# 483
# ['Tristram', 'Straylight', 'Snowdin', 'AlphaCentauri', 'Norrath', 'Faerun', 'Tambi', 'Arbre']
# 390
# ['Tristram', 'Straylight', 'Snowdin', 'Tambi', 'AlphaCentauri', 'Faerun', 'Norrath', 'Arbre']
# 381
# ['Tristram', 'Straylight', 'Snowdin', 'Tambi', 'AlphaCentauri', 'Norrath', 'Faerun', 'Arbre']
# 378
# ['Tristram', 'Straylight', 'Snowdin', 'Tambi', 'Faerun', 'AlphaCentauri', 'Norrath', 'Arbre']
# 363
# ['Tristram', 'Straylight', 'Snowdin', 'Tambi', 'Faerun', 'Norrath', 'AlphaCentauri', 'Arbre']
# 414
# ['Tristram', 'Straylight', 'Snowdin', 'Tambi', 'Norrath', 'AlphaCentauri', 'Faerun', 'Arbre']
# 460
# ['Tristram', 'Straylight', 'Snowdin', 'Tambi', 'Norrath', 'Faerun', 'AlphaCentauri', 'Arbre']
# 514
# ['Tristram', 'Straylight', 'Snowdin', 'Faerun', 'AlphaCentauri', 'Tambi', 'Norrath', 'Arbre']
# 421
# ['Tristram', 'Straylight', 'Snowdin', 'Faerun', 'AlphaCentauri', 'Norrath', 'Tambi', 'Arbre']
# 407
# ['Tristram', 'Straylight', 'Snowdin', 'Faerun', 'Tambi', 'AlphaCentauri', 'Norrath', 'Arbre']
# 321
# ['Tristram', 'Straylight', 'Snowdin', 'Faerun', 'Tambi', 'Norrath', 'AlphaCentauri', 'Arbre']
# 454
# ['Tristram', 'Straylight', 'Snowdin', 'Faerun', 'Norrath', 'AlphaCentauri', 'Tambi', 'Arbre']
# 325
# ['Tristram', 'Straylight', 'Snowdin', 'Faerun', 'Norrath', 'Tambi', 'AlphaCentauri', 'Arbre']
# 472
# ['Tristram', 'Straylight', 'Snowdin', 'Norrath', 'AlphaCentauri', 'Tambi', 'Faerun', 'Arbre']
# 423
# ['Tristram', 'Straylight', 'Snowdin', 'Norrath', 'AlphaCentauri', 'Faerun', 'Tambi', 'Arbre']
# 412
# ['Tristram', 'Straylight', 'Snowdin', 'Norrath', 'Tambi', 'AlphaCentauri', 'Faerun', 'Arbre']
# 523
# ['Tristram', 'Straylight', 'Snowdin', 'Norrath', 'Tambi', 'Faerun', 'AlphaCentauri', 'Arbre']
# 559
# ['Tristram', 'Straylight', 'Snowdin', 'Norrath', 'Faerun', 'AlphaCentauri', 'Tambi', 'Arbre']
# 430
# ['Tristram', 'Straylight', 'Snowdin', 'Norrath', 'Faerun', 'Tambi', 'AlphaCentauri', 'Arbre']
# 477
# ['Tristram', 'Straylight', 'Tambi', 'AlphaCentauri', 'Snowdin', 'Faerun', 'Norrath', 'Arbre']
# 386
# ['Tristram', 'Straylight', 'Tambi', 'AlphaCentauri', 'Snowdin', 'Norrath', 'Faerun', 'Arbre']
# 488
# ['Tristram', 'Straylight', 'Tambi', 'AlphaCentauri', 'Faerun', 'Snowdin', 'Norrath', 'Arbre']
# 408
# ['Tristram', 'Straylight', 'Tambi', 'AlphaCentauri', 'Faerun', 'Norrath', 'Snowdin', 'Arbre']
# 470
# ['Tristram', 'Straylight', 'Tambi', 'AlphaCentauri', 'Norrath', 'Snowdin', 'Faerun', 'Arbre']
# 405
# ['Tristram', 'Straylight', 'Tambi', 'AlphaCentauri', 'Norrath', 'Faerun', 'Snowdin', 'Arbre']
# 365
# ['Tristram', 'Straylight', 'Tambi', 'Snowdin', 'AlphaCentauri', 'Faerun', 'Norrath', 'Arbre']
# 428
# ['Tristram', 'Straylight', 'Tambi', 'Snowdin', 'AlphaCentauri', 'Norrath', 'Faerun', 'Arbre']
# 425
# ['Tristram', 'Straylight', 'Tambi', 'Snowdin', 'Faerun', 'AlphaCentauri', 'Norrath', 'Arbre']
# 345
# ['Tristram', 'Straylight', 'Tambi', 'Snowdin', 'Faerun', 'Norrath', 'AlphaCentauri', 'Arbre']
# 396
# ['Tristram', 'Straylight', 'Tambi', 'Snowdin', 'Norrath', 'AlphaCentauri', 'Faerun', 'Arbre']
# 447
# ['Tristram', 'Straylight', 'Tambi', 'Snowdin', 'Norrath', 'Faerun', 'AlphaCentauri', 'Arbre']
# 501
# ['Tristram', 'Straylight', 'Tambi', 'Faerun', 'AlphaCentauri', 'Snowdin', 'Norrath', 'Arbre']
# 473
# ['Tristram', 'Straylight', 'Tambi', 'Faerun', 'AlphaCentauri', 'Norrath', 'Snowdin', 'Arbre']
# 452
# ['Tristram', 'Straylight', 'Tambi', 'Faerun', 'Snowdin', 'AlphaCentauri', 'Norrath', 'Arbre']
# 368
# ['Tristram', 'Straylight', 'Tambi', 'Faerun', 'Snowdin', 'Norrath', 'AlphaCentauri', 'Arbre']
# 441
# ['Tristram', 'Straylight', 'Tambi', 'Faerun', 'Norrath', 'AlphaCentauri', 'Snowdin', 'Arbre']
# 430
# ['Tristram', 'Straylight', 'Tambi', 'Faerun', 'Norrath', 'Snowdin', 'AlphaCentauri', 'Arbre']
# 524
# ['Tristram', 'Straylight', 'Tambi', 'Norrath', 'AlphaCentauri', 'Snowdin', 'Faerun', 'Arbre']
# 465
# ['Tristram', 'Straylight', 'Tambi', 'Norrath', 'AlphaCentauri', 'Faerun', 'Snowdin', 'Arbre']
# 447
# ['Tristram', 'Straylight', 'Tambi', 'Norrath', 'Snowdin', 'AlphaCentauri', 'Faerun', 'Arbre']
# 570
# ['Tristram', 'Straylight', 'Tambi', 'Norrath', 'Snowdin', 'Faerun', 'AlphaCentauri', 'Arbre']
# 541
# ['Tristram', 'Straylight', 'Tambi', 'Norrath', 'Faerun', 'AlphaCentauri', 'Snowdin', 'Arbre']
# 530
# ['Tristram', 'Straylight', 'Tambi', 'Norrath', 'Faerun', 'Snowdin', 'AlphaCentauri', 'Arbre']
# 519
# ['Tristram', 'Straylight', 'Faerun', 'AlphaCentauri', 'Snowdin', 'Tambi', 'Norrath', 'Arbre']
# 369
# ['Tristram', 'Straylight', 'Faerun', 'AlphaCentauri', 'Snowdin', 'Norrath', 'Tambi', 'Arbre']
# 418
# ['Tristram', 'Straylight', 'Faerun', 'AlphaCentauri', 'Tambi', 'Snowdin', 'Norrath', 'Arbre']
# 309
# ['Tristram', 'Straylight', 'Faerun', 'AlphaCentauri', 'Tambi', 'Norrath', 'Snowdin', 'Arbre']
# 411
# ['Tristram', 'Straylight', 'Faerun', 'AlphaCentauri', 'Norrath', 'Snowdin', 'Tambi', 'Arbre']
# 295
# ['Tristram', 'Straylight', 'Faerun', 'AlphaCentauri', 'Norrath', 'Tambi', 'Snowdin', 'Arbre']
# 348
# ['Tristram', 'Straylight', 'Faerun', 'Snowdin', 'AlphaCentauri', 'Tambi', 'Norrath', 'Arbre']
# 327
# ['Tristram', 'Straylight', 'Faerun', 'Snowdin', 'AlphaCentauri', 'Norrath', 'Tambi', 'Arbre']
# 313
# ['Tristram', 'Straylight', 'Faerun', 'Snowdin', 'Tambi', 'AlphaCentauri', 'Norrath', 'Arbre']
# 204
# ['Tristram', 'Straylight', 'Faerun', 'Snowdin', 'Tambi', 'Norrath', 'AlphaCentauri', 'Arbre']
# 337
# ['Tristram', 'Straylight', 'Faerun', 'Snowdin', 'Norrath', 'AlphaCentauri', 'Tambi', 'Arbre']
# 253
# ['Tristram', 'Straylight', 'Faerun', 'Snowdin', 'Norrath', 'Tambi', 'AlphaCentauri', 'Arbre']
# 400
# ['Tristram', 'Straylight', 'Faerun', 'Tambi', 'AlphaCentauri', 'Snowdin', 'Norrath', 'Arbre']
# 332
# ['Tristram', 'Straylight', 'Faerun', 'Tambi', 'AlphaCentauri', 'Norrath', 'Snowdin', 'Arbre']
# 311
# ['Tristram', 'Straylight', 'Faerun', 'Tambi', 'Snowdin', 'AlphaCentauri', 'Norrath', 'Arbre']
# 269
# ['Tristram', 'Straylight', 'Faerun', 'Tambi', 'Snowdin', 'Norrath', 'AlphaCentauri', 'Arbre']
# 342
# ['Tristram', 'Straylight', 'Faerun', 'Tambi', 'Norrath', 'AlphaCentauri', 'Snowdin', 'Arbre']
# 371
# ['Tristram', 'Straylight', 'Faerun', 'Tambi', 'Norrath', 'Snowdin', 'AlphaCentauri', 'Arbre']
# 465
# ['Tristram', 'Straylight', 'Faerun', 'Norrath', 'AlphaCentauri', 'Snowdin', 'Tambi', 'Arbre']
# 273
# ['Tristram', 'Straylight', 'Faerun', 'Norrath', 'AlphaCentauri', 'Tambi', 'Snowdin', 'Arbre']
# 266
# ['Tristram', 'Straylight', 'Faerun', 'Norrath', 'Snowdin', 'AlphaCentauri', 'Tambi', 'Arbre']
# 336
# ['Tristram', 'Straylight', 'Faerun', 'Norrath', 'Snowdin', 'Tambi', 'AlphaCentauri', 'Arbre']
# 360
# ['Tristram', 'Straylight', 'Faerun', 'Norrath', 'Tambi', 'AlphaCentauri', 'Snowdin', 'Arbre']
# 389
# ['Tristram', 'Straylight', 'Faerun', 'Norrath', 'Tambi', 'Snowdin', 'AlphaCentauri', 'Arbre']
# 420
# ['Tristram', 'Straylight', 'Norrath', 'AlphaCentauri', 'Snowdin', 'Tambi', 'Faerun', 'Arbre']
# 280
# ['Tristram', 'Straylight', 'Norrath', 'AlphaCentauri', 'Snowdin', 'Faerun', 'Tambi', 'Arbre']
# 227
# ['Tristram', 'Straylight', 'Norrath', 'AlphaCentauri', 'Tambi', 'Snowdin', 'Faerun', 'Arbre']
# 215
# ['Tristram', 'Straylight', 'Norrath', 'AlphaCentauri', 'Tambi', 'Faerun', 'Snowdin', 'Arbre']
# 220
# ['Tristram', 'Straylight', 'Norrath', 'AlphaCentauri', 'Faerun', 'Snowdin', 'Tambi', 'Arbre']
# 204
# ['Tristram', 'Straylight', 'Norrath', 'AlphaCentauri', 'Faerun', 'Tambi', 'Snowdin', 'Arbre']
# 262
# ['Tristram', 'Straylight', 'Norrath', 'Snowdin', 'AlphaCentauri', 'Tambi', 'Faerun', 'Arbre']
# 343
# ['Tristram', 'Straylight', 'Norrath', 'Snowdin', 'AlphaCentauri', 'Faerun', 'Tambi', 'Arbre']
# 332
# ['Tristram', 'Straylight', 'Norrath', 'Snowdin', 'Tambi', 'AlphaCentauri', 'Faerun', 'Arbre']
# 320
# ['Tristram', 'Straylight', 'Norrath', 'Snowdin', 'Tambi', 'Faerun', 'AlphaCentauri', 'Arbre']
# 356
# ['Tristram', 'Straylight', 'Norrath', 'Snowdin', 'Faerun', 'AlphaCentauri', 'Tambi', 'Arbre']
# 267
# ['Tristram', 'Straylight', 'Norrath', 'Snowdin', 'Faerun', 'Tambi', 'AlphaCentauri', 'Arbre']
# 314
# ['Tristram', 'Straylight', 'Norrath', 'Tambi', 'AlphaCentauri', 'Snowdin', 'Faerun', 'Arbre']
# 338
# ['Tristram', 'Straylight', 'Norrath', 'Tambi', 'AlphaCentauri', 'Faerun', 'Snowdin', 'Arbre']
# 320
# ['Tristram', 'Straylight', 'Norrath', 'Tambi', 'Snowdin', 'AlphaCentauri', 'Faerun', 'Arbre']
# 380
# ['Tristram', 'Straylight', 'Norrath', 'Tambi', 'Snowdin', 'Faerun', 'AlphaCentauri', 'Arbre']
# 351
# ['Tristram', 'Straylight', 'Norrath', 'Tambi', 'Faerun', 'AlphaCentauri', 'Snowdin', 'Arbre']
# 385
# ['Tristram', 'Straylight', 'Norrath', 'Tambi', 'Faerun', 'Snowdin', 'AlphaCentauri', 'Arbre']
# 374
# ['Tristram', 'Straylight', 'Norrath', 'Faerun', 'AlphaCentauri', 'Snowdin', 'Tambi', 'Arbre']
# 287
# ['Tristram', 'Straylight', 'Norrath', 'Faerun', 'AlphaCentauri', 'Tambi', 'Snowdin', 'Arbre']
# 280
# ['Tristram', 'Straylight', 'Norrath', 'Faerun', 'Snowdin', 'AlphaCentauri', 'Tambi', 'Arbre']
# 245
# ['Tristram', 'Straylight', 'Norrath', 'Faerun', 'Snowdin', 'Tambi', 'AlphaCentauri', 'Arbre']
# 269
# ['Tristram', 'Straylight', 'Norrath', 'Faerun', 'Tambi', 'AlphaCentauri', 'Snowdin', 'Arbre']
# 303
# ['Tristram', 'Straylight', 'Norrath', 'Faerun', 'Tambi', 'Snowdin', 'AlphaCentauri', 'Arbre']
# 334
# El camino mas corto es: Tristram -> Straylight -> Norrath -> Faerun -> Tambi -> Snowdin -> AlphaCentauri -> Arbre = 141
