# %% [markdown]
# Concurso de Grupos
#
# objetivos:
# aprender a usar las bondades de numpy y list compression
#
# *   se mantendran los grupos fromados en el modulo I
#
# *   La idea es que un estudiante haga un desafio(sobre 5puntos)
#
# *   En la celda de cada desafio, poner los datos de quien lo hizo
#
# *   La calificación es individual no grupal
#
# *   El desafio extra ( opcional) es de solo sobre  5 puntos
#
# *   Cada grupo entregara un archivo o link del programa en ipynb
#
# *   Link de video explicativo de como resolvieron un(1) desafio que les parecio interezante por grupo.
#
# *   O link de video explicativo del desafio extra (opcional)

# %%
""" desafio 1 
#enunciado

#primos menores a 10:
pm10=np.array([2,3,5,7])

#ejemplo de matriz salida de "3x3"
MP10=np.array([['', '2', '3'],
              ['', '5', ''],
              ['7', '', '']])

print(MP10)
"""
# se pide:

#generalizar caulquier forma de matrix

#dar la salida matrtiz cuadrada "10x10" de MP100 (primos menores a 101)

#dar la salida matrtiz rectangular "6x12" de MP100 (primos menores a 101)
# Out:
# ' desafio 1 \n#enunciado\n\n#primos menores a 10:\npm10=np.array([2,3,5,7])\n\n#ejemplo de matriz salida de "3x3"\nMP10=np.array([[\'\', \'2\', \'3\'],\n              [\'\', \'5\', \'\'],\n              [\'7\', \'\', \'\']])\n\nprint(MP10)\n'

# %%
""" desafio 2 
#enunciado
hacer una funcion que encuentre la moda 

encontrar  la moda de :
- las columna de una matriz
- las filas de una matriz
- de toda la matriz

tomar como emplo un par de matrices 
de dimenniones aletorias mayores que 3
y de contenido aleatorio ( enteros)
"""
#compara su performace con la funcion stats.mode
from scipy import stats
import numpy as np

array = np.array([2,3,5,7])
amoda = stats.mode(array)

# %%
# !pip install opencv-python

# %%
#!conda install opencv
# Out:
# ^C

# %%
""" desafio 3
#programar usando list compresion los arboles de descion 
que se muestran en la figuras

sugerecnia crear una tabla, matriz, o dicionario de pacientes con sus indicadores como entrada
"""

from skimage import io
from PIL import Image 
import matplotlib.pylab as plt
import cv2 as cv 
from google.colab.patches import cv2_imshow # for image display

def PlotImgLink(url):
    image = io.imread(url) 
    cv2_imshow(image)

url1="https://marlin-prod.literatumonline.com/cms/attachment/fb1e3b4f-157d-47a6-9d1b-51675f794dd2/gr1.jpg"
#Fig. 1COVID-19 Preoperative Surgery Decision Tree. COVID-19 = coronavirus disease; Neg = negative; Pos = positive; post-op = postoperative. Courtesy of Cleveland Clinic Reactivation Task Force [14].
#  A useful algorithm for preoperative decision making is demonstrated in
#https://www.jmig.org/article/S1553-4650(20)30244-2/fulltext

url2="https://media.springernature.com/lw685/springer-static/image/art%3A10.1038%2Fs42256-020-0180-7/MediaObjects/42256_2020_180_Fig2_HTML.png"
#Fig. 2: A decision rule using three key features and their thresholds in absolute value.
#https://www.nature.com/articles/s42256-020-0180-7#

PlotImgLink(url1)
PlotImgLink(url2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-86b2b08ed3ff> in <module>
#      10 import matplotlib.pylab as plt
#      11 import cv2 as cv
# ---> 12 from google.colab.patches import cv2_imshow # for image display
#      13
#      14 def PlotImgLink(url):
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
""" desafio 4
#enunciado

se desea hacer una nube de palabras mas importantes de un texto
su progrma debe funcionar para una lista de texto, con un arreglo (lista de listas)
personalizar su progrma para dar importancia a una lista de palabras
la cual usted dara el peso a dichas palabras de importancia
hacer un ranking de las oraciones con mas palabras de importancia

usar numpy y list compresion para reducir el # de lineas de programación
"""

# tomar como base el siguiente codigo , el cual mejorara
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
#https://alatorax.org/es/descargar/adjunto/463-dqthcy-covid19-cc-cordobaar-mar2020.pdf
Caso_Clinico="Paciente de sexo masculino de 57 años arribo 24 horas previas a la consulta a nuestra institución proveniente de Milán, Italia. Consulta por fiebre persistente de 8 días de evolución, faringoamigdalitis y tos seca en las últimas 48 horas. Sin antecedentes patológicos previos conocidos."

stopwords={}  
comment_words = ''
  
# split the value
tokens = Caso_Clinico.split()
  
# Converts each token into lowercase
for i in range(len(tokens)):
    tokens[i] = tokens[i].lower()
  
comment_words += " ".join(tokens)+" "
wordcloud = WordCloud(width = 800, height = 800,
            background_color ='white',
            stopwords = stopwords,
            min_font_size = 10).generate(comment_words)
  
# plot the WordCloud image                       
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
  
plt.show()

#mostrar como funciona su programa para los siguientes textos

#https://virological.org/t/recombinant-sars-cov-2-genomes-involving-lineage-b-1-1-7-in-the-uk/658
Discussion=["Recombination is a frequent and well documented feature of the molecular evolution of coronaviruses [5], in the Sarbecovirus subgenus of SARS-CoV-2 [6–8] and has been inferred in SARS-CoV-2 specifically [9].",
"Recombination likely occurs in every infected individual, but in almost all cases recombination will be between nearly identical genomes (descendents of the small pool of viruses that established the infection).",
"Whilst the detection of clear examples of recombinant SARS-CoV-2 genomes in the UK is a consequence of the distinctness of the lineages involved and of the intensive genomic surveillance in the country, the frequency",
"of coinfection will be a function of incidence and lineage co-circulation in a region. Given that many other countries are experiencing incidence levels that are comparable to those in the UK during late 2020 – early 2021,",
"we predict that recombination between distinct lineages will be commonly detected wherever intensive genome sequencing is undertaken. Recombination between genetically-similar variants will be equally common but more ",
"difficult to detect. However, like all coronaviruses, the appearance of recombinant SARS-CoV-2 genomes is expected and will have no immediate implications for the trajectory of the pandemic. Recombination of the B.1.1.7",
"lineage – identified as a ‘Variant of Concern’ – is likewise unremarkable as it rapidly became the dominant lineage across the UK whilst incidence was peaking so was most likely to be a constituent of any co-infection.",
"In the same way that individual amino acid replacements in the SARS-CoV-2 genome are mostly the result of error-prone replication, and are not expected to have phenotypic effects, most recombination events are simply",
" the result of the within-host processes that occur in every infection.The recombinant genomes reported here have not been designated a Pango lineage name because they do not meet the minimum observation size criterion [10].",
" If a recombinant virus does meet the criteria then provisional rules for naming these lineages have been posted here: Pango Lineage Nomenclature: provisional rules for naming recombinant lineages."]

#https://alatorax.org/es/descargar/adjunto/463-vsxfvm-covid19-cc-eeuu-3-23.pdf
History=[["68-year-old man, returned from a trip 10 days prior to presentation",
"Presented to an urgent care with dyspnea, cough, fevers, chills, andmyalgias."],
["Diagnosed with pneumonia and prescribed doxycycline.",
"Patient’s symptoms subsequently worsened and he was sent to"],
["Barnes for further"," work-up."]]

# %%
""" desafio 5 
#enunciado

modificar el programa que genera fractales Sierpinski Carpet, usando numpy y list compresion para reducir el numero de lineas de programación
"""

# https://www.geeksforgeeks.org/python-sierpinski-carpet/
import numpy as np 
from PIL import Image 
import matplotlib.pyplot as plt

  
# total number of times the process will be repeated 
total = 5
  
# size of the image 
size = 3**total 
  
# creating an image 
square = np.empty([size, size, 3], dtype = np.uint8) 
color = np.array([255, 255, 255], dtype = np.uint8) 
  
# filling it black 
square.fill(0) 
  
for i in range(0, total + 1): 
    stepdown = 3**(total - i) 
    for x in range(0, 3**i): 
          
        # checking for the centremost square 
        if x % 3 == 1: 
            for y in range(0, 3**i): 
                if y % 3 == 1: 
                      
                    # changing its color 
                    square[y * stepdown:(y + 1)*stepdown, x * stepdown:(x + 1)*stepdown] = color 

ii=Image.fromarray(square)
ii.show()  

plt.imshow(Image.fromarray(square))

# saving the image produced 
save_file = "sierpinski.jpg"
Image.fromarray(square).save(save_file) 
  
# displaying it in console 
i = Image.open("sierpinski.jpg") 
i.show()

# %% [markdown]
# desafio extra (5 puntos) opcional
#
# Hacer una nota de recuerdo una hoja tamaño A4 horizontal con operaciones utiles con mumpy, list compresion y Matplotlib.
#
# entegrables archivo final en .pdf y  el archivo original en alguno de los siguientes fromatos: google doc (wor ppt o open office equivalentes link) o latex ovefeaf (link)
#
# ejemplos:
# https://intellipaat.com/mediaFiles/2018/12/Python-NumPy-Cheat-Sheet-.pdf
#
# https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Numpy_Python_Cheat_Sheet.pdf
#
# https://www.hb.ucsc.edu/wp-content/uploads/2017/09/numpy.pdf
#
# https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf
#
# incluir los links de pdf y archivo origianal lineas abajo:
