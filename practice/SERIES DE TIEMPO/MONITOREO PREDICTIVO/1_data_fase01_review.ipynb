# %%
# Nativos
import random as rn
import os
import sys
import gc

#calculo
import numpy as np
import pandas as pd
import scipy

#grafico
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
# %matplotlib inline
sns.set(style="whitegrid")

#warning ignore future
import warnings
# warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore")
gc.collect()


BASE_DIR = os.path.dirname(os.getcwd())
print(BASE_DIR)
if BASE_DIR not in sys.path: sys.path.append(BASE_DIR)

from utils import *
#from graphs import *


SEED = 29082013
os.environ['PYTHONHASHSEED'] = str(SEED)
np.random.seed(SEED)
rn.seed(SEED)

subfolder = "data"
os.listdir(subfolder)
# Out:
# /home/villacorta/STORAGE/tests_courses_research/practice/SERIES DE TIEMPO
# ['prd08mcs.csv',
#  'Alertas Zabbix - Septiembre.xlsx',
#  'prd08mcs.xlsx',
#  '.ipynb_checkpoints',
#  'Incidencias Resumen.xlsx',
#  'prd01mcs.csv',
#  'Categorias configuradas en ZABBIX.xlsx',
#  'prd23crm.xlsx',
#  'prd01mcs.xlsx',
#  'Métricas CPU Histórico - webmvmwlnxv11.txt',
#  'Eventos ZABBIX - Ultima Semana NOV.xlsx',
#  '.~lock.Eventos ZABBIX - Ultima Semana NOV.xlsx#',
#  'prd23crm.csv']

# %%
from slugify import slugify

# %%
alertas_septiembre = pd.read_excel(
    "{}/{}".format(subfolder, 'Alertas Zabbix - Septiembre.xlsx')
)
alertas_septiembre.columns = [slugify(col) for col in alertas_septiembre.columns]
alertas_septiembre.head()
# Out:
#    severity                time       recovery-time    status            host  \
# 0      High 2019-09-30 07:54:00 2019-09-30 08:14:00  RESOLVED   rigel_backup2
# 1      High 2019-09-30 07:53:00 2019-09-30 08:36:00  RESOLVED  gppesplcli1212
# 2      High 2019-09-30 07:50:00 2019-09-30 07:51:00  RESOLVED      dstageprod
# 3  Disaster 2019-09-30 07:49:00 2019-09-30 08:34:00  RESOLVED  gppesvlcli2253
# 4      High 2019-09-30 07:48:00 2019-09-30 07:50:00  RESOLVED  gppesplcli1041
#
#                                              problem duration  ack
# 0                            Uso de CPU Mayor al 95%      20m  Yes
# 1      Free disk space is less than 10% on volume E:      43m  Yes
# 2                            Uso de CPU Mayor al 95%       1m   No
# 3  Zabbix agent on gppesvlcli2253 is unreachable ...  44m 38s   No
# 4      Free disk space is less than 10% on volume C:       2m   No

# %%
alertas_septiembre.isnull().sum()
# Out:
# severity          0
# time              0
# recovery-time    63
# status            0
# host              0
# problem           0
# duration          0
# ack               0
# dtype: int64

# %%
pd.set_option('display.max_rows',1000)
pd.set_option('display.width', 1000)
pd.set_option('display.max_columns', 100)  
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)

alertas_septiembre[
    alertas_septiembre['recovery-time'].isnull()
].head(1000)
# Out:
#        severity                time recovery-time   status            host                                                       problem    duration  ack
# 1529   High     2019-09-27 23:53:20 NaT            PROBLEM  vmjmsprod04     Free inodes is less than 10% on volume /u01/products/JMS_DOX  1m 2d 11h   Yes
# 1785   Disaster 2019-09-27 14:19:29 NaT            PROBLEM  ibm30lp1        Zabbix agent on ibm30lp1 is unreachable for 15 minutes        1m 2d 21h   No
# 1790   High     2019-09-27 14:11:48 NaT            PROBLEM  ibm30lp1        Zabbix agent on ibm30lp1 is unreachable for 7 minutes         1m 2d 21h   No
# 1794   High     2019-09-27 13:42:16 NaT            PROBLEM  custdb01        Free inodes is less than 10% on volume /                      1m 2d 22h   Yes
# 2832   Disaster 2019-09-26 01:09:40 NaT            PROBLEM  sun70l23        Zabbix agent on sun70l23 is unreachable for 15 minutes        1m 4d 10h   No
# ...

# %%
alertas_septiembre.shape
# Out:
# (17906, 8)

# %%
list_problem_unique = list(alertas_septiembre['problem'].unique())
len(list_problem_unique)
# Out:
# 1036

# %%
alertas_septiembre['host'].unique().shape
# Out:
# (439,)

# %%
alertas_septiembre.groupby(by=['host']).size()
# Out:
# host
# BIOMHYPLNXV11                     12
# CONVHYPLNXV01                     7
# CONVHYPLNXV02                     3
# CONVHYPLNXV03                     5
# CONVHYPLNXV04                     7
# GPPESNLCLI1010                    1
# GPPESNLCLI1016                    15
# GPPESNLCLI1017                    21
# GPPESNLCLI1030                    5
# GPPESPLCLI1005                    50
# GPPESPLCLI1124                    13
# GPPESVLCLI1003                    9
# GPPESVLCLI1017                    17
# GPPESVLCLI1125                    32
# GPPESVLCLI1258                    1
# GPPESVLCLI1259                    1
# GPPESVLCLI1260                    1
# GPPESVLCLI1261                    5
# GPPESVLCLI1317                    18
# GPPESVLCLI1332                    1
# GPPESVLCLI1333                    1
# GPPESVLCLI1334                    2
# GPPESVLCLI1335                    2
# GPPESVLCLI1354                    1
# GPPESVLCLI1376                    37
# ...

# %%
[_ for _ in sorted(list(alertas_septiembre['problem'].unique())) if 'Memoria: % de uso' in _]
# Out:
# ['Memoria: % de uso > 95%  porgwplrhevlnxv01',
#  'Memoria: % de uso > 95%  porgwplrhevlnxv02',
#  'Memoria: % de uso > 95%  prd01ame',
#  'Memoria: % de uso > 95%  prd01bl',
#  'Memoria: % de uso > 95%  prd03mcs',
#  'Memoria: % de uso > 95%  prd05es',
#  'Memoria: % de uso > 95%  prd05mcs',
#  'Memoria: % de uso > 95%  prd22crm',
#  'Memoria: % de uso > 95%  prd23crm',
#  'Memoria: % de uso > 95%  prd24crm',
#  'Memoria: % de uso > 95%  vmadminprod01-1',
#  'Memoria: % de uso > 95%  vmosbatchprod01',
#  'Memoria: % de uso > 95%  vmosbatchprod02',
#  'Memoria: % de uso > 95%  vmosbcfijaprod01',
#  'Memoria: % de uso > 95%  vmosbcmovilprod01',
#  'Memoria: % de uso > 95%  vmosbonlineprod01',
#  'Memoria: % de uso > 95%  vmosbonlineprod02',
#  'Memoria: % de uso > 95%  vmwsmprod01',
#  'Memoria: % de uso > 95%  vmwsmprod02',
#  'Memoria: % de uso > 95%  vmwsmprod03',
#  'Memoria: % de uso > 95%  vmwsmprod04']
