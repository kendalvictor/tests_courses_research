# %%
# !conda install memory_profiler -y
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/villacorta/anaconda3
#
#   added / updated specs:
#     - memory_profiler
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     memory_profiler-0.55.0     |           py36_0          46 KB
#     python-3.6.8               |       h0371630_0        34.4 MB
#     ca-certificates-2018.12.5  |                0         123 KB
#     ------------------------------------------------------------
#                                            Total:        34.6 MB
#
# The following NEW packages will be INSTALLED:
#
#     memory_profiler: 0.55.0-py36_0
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2018.11.29-ha4d7672_0    conda-forge --> 2018.12.5-0
#     cryptography:    2.3.1-py36hb7f436b_1000  conda-forge --> 2.4.2-py36h1ba5d50_0
# ...

# %%
# !conda install -c conda-forge xgboost -y
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/villacorta/anaconda3
#
#   added / updated specs:
#     - xgboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     py-xgboost-0.81            |py36hf484d3e_1000          66 KB  conda-forge
#     libxgboost-0.81            |    hf484d3e_1000         3.8 MB  conda-forge
#     _py-xgboost-mutex-2.0      |            cpu_0           8 KB  conda-forge
#     xgboost-0.81               |py36hf484d3e_1000           9 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.8 MB
#
# The following NEW packages will be INSTALLED:
#
#     _py-xgboost-mutex: 2.0-cpu_0               conda-forge
#     py-xgboost:        0.81-py36hf484d3e_1000  conda-forge
#     xgboost:           0.81-py36hf484d3e_1000  conda-forge
#
# ...

# %%
# !conda install -c conda-forge/label/gcc7 xgboost -y
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/villacorta/anaconda3
#
#   added / updated specs:
#     - xgboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2018.10.15 |       ha4d7672_0         135 KB  conda-forge/label/gcc7
#     openssl-1.0.2p             |    h14c3975_1002         3.1 MB  conda-forge/label/gcc7
#     xgboost-0.81               |py36hf484d3e_1000           9 KB  conda-forge/label/gcc7
#     certifi-2018.8.24          |        py36_1001         139 KB  conda-forge/label/gcc7
#     ------------------------------------------------------------
#                                            Total:         3.4 MB
#
# The following packages will be UPDATED:
#
#     openssl:         1.0.2p-h14c3975_1002   conda-forge --> 1.0.2p-h14c3975_1002   conda-forge/label/gcc7
# ...

# %%
# !conda install -c conda-forge/label/cf201901 xgboost -y
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/villacorta/anaconda3
#
#   added / updated specs:
#     - xgboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libxgboost-0.81            |       hfc679d8_0         3.5 MB  conda-forge/label/cf201901
#     conda-4.5.12               |        py36_1000         653 KB  conda-forge/label/cf201901
#     openssl-1.0.2p             |       h470a237_2         3.1 MB  conda-forge/label/cf201901
#     certifi-2018.11.29         |        py36_1000         145 KB  conda-forge/label/cf201901
#     py-xgboost-0.81            |   py36hfc679d8_0          66 KB  conda-forge/label/cf201901
#     xgboost-0.81               |   py36hfc679d8_0           9 KB  conda-forge/label/cf201901
#     ca-certificates-2018.11.29 |       ha4d7672_0         143 KB  conda-forge/label/cf201901
# ...

# %%
# !conda install py-xgboost -y
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/villacorta/anaconda3
#
#   added / updated specs:
#     - py-xgboost
#
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2018.11.29-ha4d7672_0    conda-forge/label/cf201901 --> 2018.12.5-0
#     cryptography:    2.3.1-py36hb7f436b_1000  conda-forge                --> 2.4.2-py36h1ba5d50_0
#     curl:            7.63.0-h646f8bb_1000     conda-forge                --> 7.63.0-hbc83047_1000
#     grpcio:          1.16.0-py36h4f00d22_1000 conda-forge                --> 1.16.1-py36hf8bcb03_1
#     libcurl:         7.63.0-h01ee5af_1000     conda-forge                --> 7.63.0-h20c2e04_1000
#     openssl:         1.0.2p-h470a237_2        conda-forge/label/cf201901 --> 1.1.1a-h7b6447c_0
#     pycurl:          7.43.0.2-py36hb7f436b_0                             --> 7.43.0.2-py36h1ba5d50_0
#     python:          3.6.6-hd21baee_1003      conda-forge                --> 3.6.8-h0371630_0
# ...
