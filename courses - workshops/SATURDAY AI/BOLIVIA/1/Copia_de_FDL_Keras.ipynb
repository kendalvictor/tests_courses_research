# %% [markdown]
# # Fundamentos de Deep Learning (2/2)
# ## Neural Networks
# ## Parte 1, TensorFlow 2
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Sobre el dataset
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

# %%
fashion_dataset = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_dataset.load_data()

# %% [markdown]
# Para revisar sobre las etiquetas: [Etiquetas del Fashion MNIST](https://keras.io/api/datasets/fashion_mnist/)

# %%
class_names = ['Polera', 'Pantalon', 'Sueter', 'Vestido', 'Abrigado', 'Sandalia', 'Camisa', 'Sneaker', 'Mochila', 'Bota']
len(class_names)
# Out:
# 10

# %%
plt.figure() 
plt.imshow(np.squeeze(train_images[450]))

# %% [markdown]
# ### Holdout
# ![image.png](data:image/png;base64,...)

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# ### Normalizamos el dataset
# ![image.png](data:image/png;base64,...)

# %%
# poner codigo acá
train_images = train_images/255.0
test_images = test_images/255.0

# %% [markdown]
# ### Neural Network
# ![image.png](data:image/png;base64,...)

# %%
# poner codigo acá
model = keras.Sequential([
                          keras.layers.Flatten(input_shape=(28,28)),
                          keras.layers.Dense(128, activation = 'relu'),
                          keras.layers.Dense(10, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               100480
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Recordando los optimizadores

# %% [markdown]
# ![saddle_point_evaluation_optimizers.gif](data:image/gif;base64,...)

# %%
opt = keras.optimizers.Adam(learning_rate=0.01)

model.compile(optimizer=opt, 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4684 - accuracy: 0.8343
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4150 - accuracy: 0.8511
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.4038 - accuracy: 0.8557
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3863 - accuracy: 0.8613
# Epoch 5/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3824 - accuracy: 0.8629
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3759 - accuracy: 0.8640
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3783 - accuracy: 0.8646
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3652 - accuracy: 0.8675
# Epoch 9/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3658 - accuracy: 0.8683
# Epoch 10/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3546 - accuracy: 0.8723

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Test accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3243 - accuracy: 0.8899
# Test accuracy: 0.8899000287055969
