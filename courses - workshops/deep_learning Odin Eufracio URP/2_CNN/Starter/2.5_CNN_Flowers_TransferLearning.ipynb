# %% [markdown]
# # CNN - Transfer Learning

# %%
# !pip install -q tensorflow-gpu==2.0.0
# Out:
#      |████████████████████████████████| 380.8MB 44kB/s
#      |████████████████████████████████| 450kB 63.1MB/s
#      |████████████████████████████████| 3.8MB 52.7MB/s
#      |████████████████████████████████| 81kB 12.8MB/s
# ERROR: tensorflow 1.15.0 has requirement tensorboard<1.16.0,>=1.15.0, but you'll have tensorboard 2.0.1 which is incompatible.
# ERROR: tensorflow 1.15.0 has requirement tensorflow-estimator==1.15.1, but you'll have tensorflow-estimator 2.0.1 which is incompatible.
# ERROR: tensorboard 2.0.1 has requirement grpcio>=1.24.3, but you'll have grpcio 1.15.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement google-auth~=1.4.0, but you'll have google-auth 1.7.0 which is incompatible.

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib
print(tf.__version__, tf.test.gpu_device_name())
device_lib.list_local_devices()
# Out:
# 2.0.0 /device:GPU:0
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 820789328814672174, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 12503114528942530155
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 18331644307211153703
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15956161332
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 9671996285712561472
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
# !pip install tensorflow_hub
import tensorflow_hub as hub
# Out:
# Requirement already satisfied: tensorflow_hub in /usr/local/lib/python3.6/dist-packages (0.7.0)
# Requirement already satisfied: protobuf>=3.4.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow_hub) (3.10.0)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow_hub) (1.17.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow_hub) (1.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.4.0->tensorflow_hub) (41.4.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the data

# %%
IMAGE_SHAPE = (224, 224)

# %%
data_path = tf.keras.utils.get_file(
  'flower_photos','https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz',
   untar=True)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228818944/228813984 [==============================] - 2s 0us/step

# %%
data_path
# Out:
# '/root/.keras/datasets/flower_photos'

# %%
# !ls -lah /root/.keras/datasets/flower_photos
# Out:
# total 620K
# drwxr-x--- 7 270850 5000 4.0K Feb 10  2016 .
# drwxr-xr-x 3 root   root 4.0K Nov  8 02:19 ..
# drwx------ 2 270850 5000  36K Feb 10  2016 daisy
# drwx------ 2 270850 5000  52K Feb 10  2016 dandelion
# -rw-r----- 1 270850 5000 409K Feb  9  2016 LICENSE.txt
# drwx------ 2 270850 5000  36K Feb 10  2016 roses
# drwx------ 2 270850 5000  36K Feb 10  2016 sunflowers
# drwx------ 2 270850 5000  40K Feb 10  2016 tulips

# %%
image_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1.0/255.0)

# %%
image_data = image_generator.flow_from_directory(str(data_path), target_size=IMAGE_SHAPE)
# Out:
# Found 3670 images belonging to 5 classes.

# %%
for image_batch, label_batch in image_data:
  print("Image batch shape: ", image_batch.shape)
  print("Label batch shape: ", label_batch.shape)
  break
# Out:
# Image batch shape:  (32, 224, 224, 3)
# Label batch shape:  (32, 5)

# %% [markdown]
# ## Load pre-trained model

# %%
mobilenetV2_URL = 'https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/2'

# %%
mobilenetV2 = hub.KerasLayer(mobilenetV2_URL, input_shape= IMAGE_SHAPE + (3,))

# %%
mobilenetV2.trainable = False

# %% [markdown]
# ## Play with the data

# %%
fig1, ax1 = plt.subplots(nrows=5, ncols=5, figsize=(12, 10));

# %%
for i in range(5):
		for j in range(5):
			ax1[i, j].axis('off')
			ax1[i, j].grid(False)
			ax1[i, j].set_xticks([])
			ax1[i, j].set_yticks([])

# %%
index = 0;
for i in range(5):
    for j in range(5):
        ax1[i, j].imshow(image_batch[index])
        index += 1

# %%
fig1

# %% [markdown]
# ## Build the model

# %%
model = tf.keras.Sequential()

# %%
model.add(mobilenetV2)
model.add(tf.keras.layers.Dense(image_data.num_classes, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# dense (Dense)                (None, 5)                 6405
# =================================================================
# Total params: 2,264,389
# Trainable params: 6,405
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
model.compile( optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Train the model

# %%
steps_per_epoch = np.ceil(image_data.samples/image_data.batch_size)

# %%
result = model.fit_generator(image_data, epochs=10, steps_per_epoch=steps_per_epoch)
# Out:
# Epoch 1/10
# 115/115 [==============================] - 33s 287ms/step - loss: 0.6730 - accuracy: 0.7621
# Epoch 2/10
# 115/115 [==============================] - 24s 212ms/step - loss: 0.3404 - accuracy: 0.8913
# Epoch 3/10
# 115/115 [==============================] - 24s 212ms/step - loss: 0.2666 - accuracy: 0.9193
# Epoch 4/10
# 115/115 [==============================] - 24s 212ms/step - loss: 0.2257 - accuracy: 0.9308
# Epoch 5/10
# 115/115 [==============================] - 24s 211ms/step - loss: 0.1925 - accuracy: 0.9411
# Epoch 6/10
# 115/115 [==============================] - 24s 211ms/step - loss: 0.1676 - accuracy: 0.9556
# Epoch 7/10
# 115/115 [==============================] - 24s 211ms/step - loss: 0.1534 - accuracy: 0.9594
# Epoch 8/10
# 115/115 [==============================] - 24s 210ms/step - loss: 0.1343 - accuracy: 0.9668
# Epoch 9/10
# 115/115 [==============================] - 25s 214ms/step - loss: 0.1228 - accuracy: 0.9695
# Epoch 10/10
# 115/115 [==============================] - 24s 211ms/step - loss: 0.1134 - accuracy: 0.9725

# %% [markdown]
# ## Evaluate the model

# %%
plt.plot(result.history['loss'], label='loss')
plt.legend()

# %%
plt.plot(result.history['accuracy'], label='acc')
plt.legend()
