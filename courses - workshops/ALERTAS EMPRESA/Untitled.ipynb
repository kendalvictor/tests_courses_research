# %%
import pandas as pd

pd.read_csv('https://drive.google.com/file/d/1ApgOGYvQHkHK7qRYa7Ajp3gUSnMQjd7D/view?usp=sharing')
# Out:
#     <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style>@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>vacunacion.csv - Google Drive</title><meta property="og:title" content="vacunacion.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta pr
# ...

# %%
data = pd.read_csv('https://cloud.minsa.gob.pe/s/ZgXoXqK2KLjRLxD/download')
print(data.shape)  # 340429

data.head(3)
# Out:
# (340249, 12)
#    FECHA_CORTE                              UUID       GRUPO_RIESGO  EDAD  \
# 0     20210304  c7ba6f9424c59a543e8803495c1061db  PERSONAL DE SALUD  39.0
# 1     20210304  51ffbe83478f1e64da17fe2756a9594b  PERSONAL DE SALUD  37.0
# 2     20210304  54048fe3b06c35f14350d7e81340bdbd  PERSONAL DE SALUD  44.0
#
#         SEXO  FECHA_VACUNACION  DOSIS FABRICANTE      DIRESA DEPARTAMENTO  \
# 0  MASCULINO          20210225      1  SINOPHARM  LAMBAYEQUE   LAMBAYEQUE
# 1   FEMENINO          20210219      1  SINOPHARM  LAMBAYEQUE   LAMBAYEQUE
# 2  MASCULINO          20210220      1  SINOPHARM  LAMBAYEQUE   LAMBAYEQUE
#
#   PROVINCIA             DISTRITO
# 0  CHICLAYO             CHICLAYO
# 1  CHICLAYO  JOSE LEONARDO ORTIZ
# 2  CHICLAYO  JOSE LEONARDO ORTIZ

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 340249 entries, 0 to 340248
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   FECHA_CORTE       340249 non-null  int64
#  1   UUID              340249 non-null  object
#  2   GRUPO_RIESGO      340249 non-null  object
#  3   EDAD              340068 non-null  float64
#  4   SEXO              338932 non-null  object
#  5   FECHA_VACUNACION  340249 non-null  int64
#  6   DOSIS             340249 non-null  int64
#  7   FABRICANTE        340249 non-null  object
#  8   DIRESA            340249 non-null  object
#  9   DEPARTAMENTO      340249 non-null  object
#  10  PROVINCIA         340249 non-null  object
#  11  DISTRITO          340249 non-null  object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 31.2+ MB

# %%
# !pip install mysql-connector-python

# %%
import pandas as pd
#import config
#SQL
import mysql.connector 
from mysql.connector import errorcode
from sqlalchemy import create_engine

# %%
pd.read_excel('https://docs.google.com/spreadsheets/d/1M5AppwH12EZOaxx_Y0HJLzN2NURHcRB3Lq9fJJmr2V8/edit?usp=sharing')
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-3-cbc633cfa481> in <module>
# ----> 1 pd.read_excel('https://docs.google.com/spreadsheets/d/1M5AppwH12EZOaxx_Y0HJLzN2NURHcRB3Lq9fJJmr2V8/edit?usp=sharing')
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...
