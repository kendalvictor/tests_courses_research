# %%
import os
def igresa(ruc, driver):
    element = driver.find_element_by_xpath('//*[@id="txtRuc"]')
    element.send_keys(ruc)
    time.sleep(1)
    
    
    #tt = driver.execute_script("return document.getElementById('recaptcha-token').value")
    #print(tt)
    #print("get token")
    driver.execute_script("getTokenCaptcha3()")
    #driver.execute_script("getTokenCaptcha3()")
    time.sleep(10)
    print("Esperé 10 segundos")
    element = driver.find_element_by_xpath('//*[@class="btn btn-primary btn-sm btnInfNumTra"]')
    element.click()
    
    return element
        
        
        
        
def extrae(ruc, driver):
    element = driver.find_element_by_xpath('//*[@id="txtRuc"]')
    element.send_keys(ruc) #ingresa ruc a consultar
        
#     element = driver.find_element_by_xpath('/html/body/form/table/tbody/tr/td/table[2]/tbody/tr[1]/td[6]/input')
#     element.send_keys(texto1) #ingresa código captcha
    driver.execute_script(
    """
    /* PLEASE DO NOT COPY AND PASTE THIS CODE. */(function(){var w=window,C='___grecaptcha_cfg',cfg=w[C]=w[C]||{},N='grecaptcha';var gr=w[N]=w[N]||{};gr.ready=gr.ready||function(f){(cfg['fns']=cfg['fns']||[]).push(f);};w['__recaptcha_api']='https://www.google.com/recaptcha/api2/';(cfg['render']=cfg['render']||[]).push('6Ld0ZLsZAAAAAJb1R6KIom0xEN84iT6QJLWo8S9n');w['__google_recaptcha_client']=true;var d=document,po=d.createElement('script');po.type='text/javascript';po.async=true;po.src='https://www.gstatic.com/recaptcha/releases/2Mfykwl2mlvyQZQ3PEgoH710/recaptcha__es.js';po.crossOrigin='anonymous';po.integrity='sha384-71pW1g7u5Bmv/r3N6DI1vJW86VvHc1QVJW/82zt1IFM28F9pSCArE1Ket2c7/lya';var e=d.querySelector('script[nonce]'),n=e&&(e['nonce']||e.getAttribute('nonce'));if(n){po.setAttribute('nonce',n);}var s=d.getElementsByTagName('script')[0];s.parentNode.insertBefore(po, s);})();
    """)
    
    time.sleep(3)
    print("Intento de obtener el captcha")
    driver.execute_script("""
        var site_key_sunat='6Ld0ZLsZAAAAAJb1R6KIom0xEN84iT6QJLWo8S9n';
        
    	function getTokenCaptcha3(){
    		  grecaptcha.ready(function() {
                  grecaptcha.execute(site_key_sunat, {action: 'consultaRUC01'}).then(function(token) {
                       var paramCaptcha = {"token":token};
                       $.redirectPost(URL_CONTEXT_PATH + "/gestionAlerta/registrarCompraPresencialDirecExacta", paramCaptcha);
                      
	                  if(validaFormulario()){
	      	            enviaAceptar(token);
	      	        	}
	      	       // event.preventDefault();
	      	       // event.stopPropagation();
      	        
                  });
            });    		
    	}
        getTokenCaptcha3()
    """)
    #element = driver.find_element_by_xpath('//*[@id="btnAceptar"]')
    #element.click() #presiona buscar    
     
    time.sleep(3)
        # Do you task here 
    #save_cookie(driver)
    #for handle in driver.window_handles:
    #    driver.switch_to_window(handle)

    element = driver.find_element_by_xpath('//*[@class="btn btn-primary btn-sm btnInfNumTra"]')
    element.click()
    
    element = driver.find_element_by_xpath('//tbody//tr//td')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr//td[2]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr//td[3]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr//td[4]')
    olo.append(element.text)
    
    element = driver.find_element_by_xpath('//tbody//tr[2]//td')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[2]//td[2]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[2]//td[3]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[2]//td[4]')
    olo.append(element.text)
    
    element = driver.find_element_by_xpath('//tbody//tr[3]//td')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[3]//td[2]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[3]//td[3]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[3]//td[4]')
    olo.append(element.text)
    
    element = driver.find_element_by_xpath('//tbody//tr[4]//td')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[4]//td[2]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[4]//td[3]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[4]//td[4]')
    olo.append(element.text)
    
    element = driver.find_element_by_xpath('//tbody//tr[5]//td')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[5]//td[2]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[5]//td[3]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[5]//td[4]')
    olo.append(element.text)
    
    element = driver.find_element_by_xpath('//tbody//tr[6]//td')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[6]//td[2]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[6]//td[3]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[6]//td[4]')
    olo.append(element.text)
    
    element = driver.find_element_by_xpath('//tbody//tr[7]//td')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[7]//td[2]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[7]//td[3]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[7]//td[4]')
    olo.append(element.text)
    
    element = driver.find_element_by_xpath('//tbody//tr[8]//td')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[8]//td[2]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[8]//td[3]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[8]//td[4]')
    olo.append(element.text)
    
    element = driver.find_element_by_xpath('//tbody//tr[9]//td')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[9]//td[2]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[9]//td[3]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[9]//td[4]')
    olo.append(element.text)
    
    element = driver.find_element_by_xpath('//tbody//tr[10]//td')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[10]//td[2]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[10]//td[3]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[10]//td[4]')
    olo.append(element.text)
    
    element = driver.find_element_by_xpath('//tbody//tr[11]//td')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[11]//td[2]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[11]//td[3]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[11]//td[4]')
    olo.append(element.text)
    
    element = driver.find_element_by_xpath('//tbody//tr[12]//td')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[12]//td[2]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[12]//td[3]')
    olo.append(element.text)
    element = driver.find_element_by_xpath('//tbody//tr[12]//td[4]')
    olo.append(element.text)
    
    
    
#     element = driver.find_element_by_xpath('//*[@class="list-group"]//div[3]//div//div[2]')
#     print(element)
    
    return element

# %%
import random

def save_cookie(driver):
    with open("cookie", 'wb') as filehandler:
        pickle.dump(driver.get_cookies(), filehandler)
        
def load_cookie(driver):
    with open("cookie", 'rb') as cookiesfile:
        cookies = pickle.load(cookiesfile)
        for cookie in cookies:
            print(cookie)
            driver.add_cookie(cookie)

def get_driver(proxy=False):
    user_agent = [
        'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.132 Safari/537.36',
        'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/71.0.3578.80 Chrome/88.0.4324.104 Safari/537.36',
        'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.146 Safari/537.36'
    ]
    agente = user_agent[1]#random.choice(user_agent)
    agente = 'Chrome/73.0.3683.86'
    #print(agente)
    
    opts = Options()
    opts.add_argument('user-agent={}'.format(agente))
    #opts.add_experimental_option( "prefs",{'profile.managed_default_content_settings.javascript': 2})
    opts.add_experimental_option('excludeSwitches', ['load-extension', 'enable-automation'])
    #opts.add_argument("--incognito")
    #opts.add_argument('--no-sandbox')
    #opts.add_argument("--allow-running-insecure-content")
    #opts.add_argument('--disable-extensions')
    #opts.add_argument("--user-data-dir=chrome-data")
    #opts.add_argument("start-maximized")
    opts.add_argument("--enable-javascript")
    #opts.add_argument("--disable-web-security")
    #opts.add_argument("--disable-extensions")
    opts.add_argument("--auto-open-devtools-for-tabs")
    username = os.getenv("USERNAME")
    userProfile = "C:\\Users\\" + username + "\\AppData\\Local\\Google\\Chrome\\User Data\\Default"
    #print(userProfile)
    #opts.add_argument("user-data-dir={}".format(userProfile))
    
    if proxy:
        PROXY = "34.216.89.174:53281"
        opts.add_argument('--proxy-server=%s' % PROXY)
        #opts.add_argument('--disable-software-rasterizer')
        opts.add_argument("--disable-web-security")
        print(PROXY)
    else:
        #opts.add_argument('--no-proxy-server') 
        pass
    
    driver = webdriver.Chrome('./chromedriver.exe', options=opts)
    
    return driver
    
def itera_ruc(ruc, max_iter=3):
    #driver = get_driver(proxy=False)
    #driver.get("https://e-consultaruc.sunat.gob.pe/cl-ti-itmrconsruc/jcrS00Alias")
    #load_cookie(driver)
    time.sleep(5)
    ii = -1
    while ii <= max_iter:
        driver = get_driver(proxy=False)
        driver.get("https://e-consultaruc.sunat.gob.pe/cl-ti-itmrconsruc/jcrS00Alias")
        ii += 1
        print("intento {}_".format(ii))
        try:
            #return extrae(ruc, driver).text
            return igresa(ruc, driver).text
        except Exception as e:
            pass

        driver.quit()
            #driver = get_driver(proxy=False) if ii < max_iter else get_driver(proxy=True)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
import pytesseract as tess
from PIL import Image
# import cv2
import time
import xlsxwriter
import datetime
import pandas as pd
import csv
from datetime import datetime
import math
import numpy as np
import openpyxl
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import UnexpectedAlertPresentException
from selenium.common.exceptions import WebDriverException
#opts = Options()
#opts.add_argument("user-agent=Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/71.0.3578.80 Chrome/88.0.4324.104 Safari/537.36")


nombArch = str("fuente.xlsx")

cantRuc = int(input("Ingrese la cantidad de RUC: "))

#driver = webdriver.Chrome('./chromedriver.exe', options=opts)

excel_document = openpyxl.load_workbook(nombArch)
sheet = excel_document['Hoja1']



lista_1 = [] #lista de ruc a ser consultada
lista_2 = []

multiple_cells = sheet['A480':'A'+str(cantRuc +479 )]

for row in multiple_cells:
    for cell in row:
        lista_1.append(str(cell.value))
        
print (lista_1)


cant = 0
m = 1330
numRuc = 0
fila=0

r = 2
u = -1
workbook   = xlsxwriter.Workbook('fuente.xlsx')
worksheet1 = workbook.add_worksheet()

wb = openpyxl.Workbook() 

sheet = wb.active 
 
ini = time.time()

print(lista_1)
for ruc in sorted(lista_1, reverse=True)[::-1]: #para cada ruc de la lista se realiza el scraping
    s = 0

    #driver.delete_all_cookies()
    #driver.refresh()
    #driver.get("https://e-consultaruc.sunat.gob.pe/cl-ti-itmrconsruc/jcrS00Alias")
    #time.sleep(5)
    
#     img = driver.find_element_by_xpath('/html/body/form/table/tbody/tr/td/table[2]/tbody/tr[1]/td[5]/img')
     
#     procesar(img)
    
#     texto1 = pytesseract().upper()
    
    ruc1 = ruc[:2]
    #print()
    numRuc = numRuc + 1 
    print ("ruc", ruc, numRuc)
#     texto2=len(texto1) 
    
    olo = []
    try:        
        
        #a = extrae(ruc).text
        a = itera_ruc(ruc, max_iter=3)
        print("-"*50, a)
        u = u + 1
        print("✔")
    

        fila = fila + 1
        j = 1
        while j < 13:
            m = sheet.cell(row=j+12*u, column= 1)
            m.value=ruc
            j=j+1
           
        d=1
        while s<48:
            c2 = sheet.cell(row= d +12*u , column = r) 
            c2.value = olo[s] 
            s=s+1 
           
            if s==4 :
                d=d+1
            if s==8 :
                d=d+1
            if s==12 :
                d=d+1
            if s==16 :
                d=d+1
            if s==20 :
                d=d+1
            if s==24 :
                d=d+1
            if s==28 :
                d=d+1
            if s==32 :
                d=d+1
            if s==36 :
                d=d+1
            if s==40 :
                d=d+1
            if s==44 :
                d=d+1
            
            
            if r==5 :
                r=1
            
            
            r=r+1

    except Exception as e:
        print("x", str(e))
    
    wb.save("C:\\Users\\Villacorta\\Desktop\\REVIEW\\SUNAT\\1.xlsx") 
    
    

wb.save("C:\\Users\\Villacorta\\Desktop\\REVIEW\\SUNAT\\1.xlsx") 
fin = time.time()


print ((fin - ini)/60)
#driver.quit()
print("finish")
# print(lista_2)
# Out:
# Ingrese la cantidad de RUC:  11
# ['20521477602', '20521314720', '20521302390', '20521282003', '20521213371', '20521204622', '20521178362', '20521086832', '20520967151', '20520900595', '20520866630']
# ['20521477602', '20521314720', '20521302390', '20521282003', '20521213371', '20521204622', '20521178362', '20521086832', '20520967151', '20520900595', '20520866630']
# ruc 20520866630 1
# intento 0_
# Esperé 10 segundos
# intento 1_
# Esperé 10 segundos
# intento 2_
# Esperé 10 segundos
# intento 3_

# %%
s=len(olo)

# %%
s
