# %% [markdown]
# # Single neuron: linear regression

# %%
# !pip install -q tensorflow-gpu==2.0.0
# Out:
#      |████████████████████████████████| 380.8MB 42kB/s
#      |████████████████████████████████| 450kB 52.4MB/s
#      |████████████████████████████████| 3.8MB 31.3MB/s
#      |████████████████████████████████| 81kB 11.4MB/s
# ERROR: tensorflow 1.15.0 has requirement tensorboard<1.16.0,>=1.15.0, but you'll have tensorboard 2.0.1 which is incompatible.
# ERROR: tensorflow 1.15.0 has requirement tensorflow-estimator==1.15.1, but you'll have tensorflow-estimator 2.0.1 which is incompatible.
# ERROR: tensorboard 2.0.1 has requirement grpcio>=1.24.3, but you'll have grpcio 1.15.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement google-auth~=1.4.0, but you'll have google-auth 1.7.0 which is incompatible.

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib
print(tf.__version__, tf.test.gpu_device_name())
device_lib.list_local_devices()
# Out:
# 2.0.0 /device:GPU:0
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 431690263798178656, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 9281904458652256597
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 5688590728078566662
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15956161332
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 16587206429061235460
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Load the data

# %%
data = load_boston()

# %% [markdown]
# ## Play with the data

# %%
type(data)
# Out:
# sklearn.utils.Bunch

# %%
dir(data)
# Out:
# ['DESCR', 'data', 'feature_names', 'filename', 'target']

# %%
print(data.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
print(data.data.shape)
print(data.data)
# Out:
# (506, 13)
# [[6.3200e-03 1.8000e+01 2.3100e+00 ... 1.5300e+01 3.9690e+02 4.9800e+00]
#  [2.7310e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9690e+02 9.1400e+00]
#  [2.7290e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9283e+02 4.0300e+00]
#  ...
#  [6.0760e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 5.6400e+00]
#  [1.0959e-01 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9345e+02 6.4800e+00]
#  [4.7410e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 7.8800e+00]]

# %%
print(data.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
print(data.target.shape)
print(data.target)
# Out:
# (506,)
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
#  17.  15.6 13.1 41.3 24.3 23.3 27.  50.  50.  50.  22.7 25.  50.  23.8
#  23.8 22.3 17.4 19.1 23.1 23.6 22.6 29.4 23.2 24.6 29.9 37.2 39.8 36.2
# ...

# %%
df = pd.DataFrame(data.data, columns=data.feature_names)
df['MEDV'] = data.target
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.heatmap(data= df.corr().round(2) , annot=True);

# %%
X = df['RM'].values
Y = df['MEDV'].values

# %%
plt.scatter(X, Y)
plt.xlabel('Average number of rooms')
plt.ylabel('House Prices')
# Out:
# Text(0, 0.5, 'House Prices')

# %% [markdown]
# ## Prepare the data

# %%
x_train,  y_train = X, Y

# %% [markdown]
# ## Build the model

# %%
model = tf.keras.models.Sequential()

# %%
model.add( tf.keras.layers.Dense(units=1, input_shape=(1,)) )

# %%
model.compile( optimizer=tf.keras.optimizers.SGD(learning_rate=0.001,momentum=0.9), loss='mse' )

# %% [markdown]
# ## Train the model

# %%
result = model.fit( x=x_train, y=y_train, epochs= 300 )
# Out:
# Train on 506 samples
# Epoch 1/300
# 506/506 [==============================] - 0s 797us/sample - loss: 255.3924
# Epoch 2/300
# 506/506 [==============================] - 0s 72us/sample - loss: 86.6177
# Epoch 3/300
# 506/506 [==============================] - 0s 75us/sample - loss: 68.1318
# Epoch 4/300
# 506/506 [==============================] - 0s 71us/sample - loss: 59.2777
# Epoch 5/300
# 506/506 [==============================] - 0s 68us/sample - loss: 63.2693
# Epoch 6/300
# 506/506 [==============================] - 0s 69us/sample - loss: 58.6511
# Epoch 7/300
# 506/506 [==============================] - 0s 70us/sample - loss: 60.0998
# Epoch 8/300
# 506/506 [==============================] - 0s 73us/sample - loss: 59.3766
# Epoch 9/300
# 506/506 [==============================] - 0s 68us/sample - loss: 58.4341
# Epoch 10/300
# 506/506 [==============================] - 0s 72us/sample - loss: 58.0876
# Epoch 11/300
# ...

# %%
plt.plot(result.history['loss'], label='loss')
plt.legend()

# %% [markdown]
# ## Make Predictions

# %%
Y_hat = model.predict(X).flatten()
plt.scatter(X, Y)
plt.plot(X, Y_hat)

# %%
w, b = model.layers[0].get_weights()
print(w)
print(b)
# Out:
# [[8.433521]]
# [-29.510494]

# %% [markdown]
# ## Save the model

# %%
model.save('linearregression.h5')

# %%
# !ls -lah

# %%
model2 = tf.keras.models.load_model('linearregression.h5')

# %%
Y_newhat = model2.predict(X).flatten()
plt.scatter(X, Y)
plt.plot(X, Y_newhat)
